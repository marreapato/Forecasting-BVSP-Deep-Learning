# %% [markdown]
# <a href="https://colab.research.google.com/github/marreapato/Forecasting-BVSP-Deep-Learning/blob/main/C%C3%B3pia_de_Baseline_Com_30Lags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tentando Aplicar o Shap

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, GRU# captum (biblioteca de interpretação pytorch)
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Download data for the stock (I'm using the Bovespa index as an example)
data = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data = data[['Close']]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(16,8))
plt.title("Pontos de Fechamento (Histórico)")
plt.plot(data["Close"])
plt.xlabel("Data",fontsize=18)
plt.ylabel("Indice Bovespa",fontsize=18)
plt.show()

# %%
look_back=30

# %%
last_rows=(len(data['Close'])-look_back)-int((len(data['Close'].values.reshape(-1, 1)[:])-look_back)*0.8)
last_rows
# Out:
# 825

# %%
size_of_slice=round((len(data['Close'].values.reshape(-1, 1)[:]))*0.8)
size_of_slice=size_of_slice+(len(data)-(size_of_slice+last_rows))
size_of_slice
# Out:
# 3329

# %%
# Normalize the data
scaler = MinMaxScaler()
data_train=pd.DataFrame(scaler.fit_transform(data['Close'].values.reshape(-1, 1)[0:size_of_slice]),columns=data.columns,index=data['Close'].index[0:size_of_slice])#use fit only in training that is wrong
data_test=pd.DataFrame(scaler.transform(data['Close'].values.reshape(-1, 1)[size_of_slice:size_of_slice+last_rows]),columns=data.columns,index=data['Close'].index[size_of_slice:size_of_slice+last_rows])#use fit only in training that is wrong

# %%
data_train=data_train.append(data_test)
# Out:
# <ipython-input-7-b2b194944e63>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_train=data_train.append(data_test)

# %%
len(data_train)==len(data)
# Out:
# True

# %%
data_train
# Out:
#                Close
# Date
# 2007-01-02  0.177017
# 2007-01-03  0.166606
# 2007-01-04  0.161888
# 2007-01-05  0.142186
# 2007-01-08  0.148680
# ...              ...
# 2023-10-09  0.951472
# 2023-10-10  0.969021
# 2023-10-11  0.972506
# 2023-10-13  0.958110
# 2023-10-16  0.966768
#
# [4154 rows x 1 columns]

# %%
# Normalize the data
#scaler = MinMaxScaler()
#data['Close'] = scaler.fit_transform(data['Close'].values.reshape(-1, 1))#use fit only in training that is wrong


def create_lagged_dataframe(data, lags, include_lag0=False):
    lagged_data = data.copy()

    if include_lag0:
        lagged_data['lag0'] = lagged_data['Close']

    for lag in range(1, lags + 1):
        lagged_data[f'lag{lag}'] = lagged_data['Close'].shift(lag)

    return lagged_data
# Split the data into train and test sets


# Create lag features for the entire dataset
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data_train, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values

train_size = int(len(lagged_data) * 0.8)
test_size = len(lagged_data) - train_size
train, test = lagged_data[0:train_size], lagged_data[train_size:len(data)]

# %%
trainX= train.drop(columns='Close').values
testX = test.drop(columns='Close').values
trainY= train['Close'].values
testY= test['Close'].values

print("TrainX shape:", trainX.shape)
print("TrainY shape:", trainY.shape)
print("TestX shape:", testX.shape)
print("TestY shape:", testY.shape)
# Out:
# TrainX shape: (3299, 30)
# TrainY shape: (3299,)
# TestX shape: (825, 30)
# TestY shape: (825,)

# %%
trainX.shape
# Out:
# (3299, 30)

# %%
trainX = np.array(trainX)
testX = np.array(testX)

# %%
import tensorflow as tf

tf.random.set_seed(22)

# Reshape the input data for LSTM and GRU models
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Define the GRU model
def GRU_Model(output_window):
    model = Sequential()
    model.add(GRU(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Define the LSTM model
def LSTM_Model(output_window):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Define the LSTM model
def biLSTM_Model(output_window):
    # n_steps = x_train.shape[-2]
    # n_features = x_train.shape[-1]
    model = Sequential()
    # model.add(tf.keras.layers.Embedding(1, 6, mask_zero=True))


    model.add(Bidirectional(LSTM(64, activation='relu', input_shape=(output_window, 1), return_sequences=True)))
    model.add(Bidirectional(LSTM(32, activation='relu', return_sequences=True)))
    model.add(Bidirectional(LSTM(16, activation='relu')))
    # model.add(LSTM(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer , loss='mean_squared_error')
    return model


# Define the baseline model
def baseline_model(output_window):
    last_known_value = trainY[-1]
    return np.full((len(testY), output_window), last_known_value)

# Train and evaluate the models
output_window = 1
gru_model = GRU_Model(output_window)
lstm_model = LSTM_Model(output_window)
bilstm_model = biLSTM_Model(output_window)

gru_model.fit(trainX, trainY, epochs=300, batch_size=64)
lstm_model.fit(trainX, trainY, epochs=300, batch_size=64)
bilstm_model.fit(trainX, trainY, epochs=300, batch_size=64)

bilstm_predictions = bilstm_model.predict(testX)
gru_predictions = gru_model.predict(testX)
lstm_predictions = lstm_model.predict(testX)
baseline_predictions = baseline_model(output_window)

# Inverse transform the predictions
gru_predictions = scaler.inverse_transform(gru_predictions)
lstm_predictions = scaler.inverse_transform(lstm_predictions)
baseline_predictions = scaler.inverse_transform(baseline_predictions)
# Inverse transform the predictions
bilstm_predictions = scaler.inverse_transform(bilstm_predictions)
# Out:
# Epoch 1/300
# 52/52 [==============================] - 3s 5ms/step - loss: 0.0135
# Epoch 2/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 3/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.4687e-04
# Epoch 4/300
# 52/52 [==============================] - 0s 5ms/step - loss: 7.9417e-04
# Epoch 5/300
# 52/52 [==============================] - 0s 5ms/step - loss: 6.6455e-04
# Epoch 6/300
# 52/52 [==============================] - 0s 5ms/step - loss: 5.7256e-04
# Epoch 7/300
# 52/52 [==============================] - 0s 5ms/step - loss: 5.2742e-04
# Epoch 8/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.7721e-04
# Epoch 9/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.3920e-04
# Epoch 10/300
# 52/52 [==============================] - 0s 6ms/step - loss: 4.1900e-04
# Epoch 11/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.2244e-04
# Epoch 12/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.7753e-04
# Epoch 13/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.7411e-04
# Epoch 14/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.3653e-04
# Epoch 15/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.1522e-04
# Epoch 16/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.0794e-04
# Epoch 17/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.0109e-04
# Epoch 18/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.0009e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.8536e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7815e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7902e-04
# Epoch 22/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.8191e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6264e-04
# Epoch 24/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.9006e-04
# Epoch 25/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5449e-04
# Epoch 26/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4009e-04
# Epoch 27/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6039e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2698e-04
# Epoch 29/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4511e-04
# Epoch 30/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7058e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4198e-04
# Epoch 32/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.1648e-04
# Epoch 33/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.4975e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.2490e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1395e-04
# Epoch 36/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0698e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0958e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.4584e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0228e-04
# Epoch 40/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0990e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.1048e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9857e-04
# Epoch 43/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9240e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1638e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5201e-04
# Epoch 46/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6194e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3022e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2682e-04
# Epoch 49/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4179e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2264e-04
# Epoch 51/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6587e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2758e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9148e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1332e-04
# Epoch 55/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4384e-04
# Epoch 56/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0390e-04
# Epoch 57/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8516e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8407e-04
# Epoch 59/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8230e-04
# Epoch 60/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8659e-04
# Epoch 61/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9891e-04
# Epoch 62/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0668e-04
# Epoch 63/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1656e-04
# Epoch 64/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0363e-04
# Epoch 65/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9549e-04
# Epoch 66/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3540e-04
# Epoch 67/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2185e-04
# Epoch 68/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9338e-04
# Epoch 69/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3379e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.8925e-04
# Epoch 71/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2619e-04
# Epoch 72/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1494e-04
# Epoch 73/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0764e-04
# Epoch 74/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8470e-04
# Epoch 75/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9333e-04
# Epoch 76/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8460e-04
# Epoch 77/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.0876e-04
# Epoch 78/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8224e-04
# Epoch 79/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2497e-04
# Epoch 80/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8264e-04
# Epoch 81/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8799e-04
# Epoch 82/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0211e-04
# Epoch 83/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8341e-04
# Epoch 84/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9673e-04
# Epoch 85/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.1339e-04
# Epoch 86/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8094e-04
# Epoch 87/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7671e-04
# Epoch 88/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8247e-04
# Epoch 89/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7502e-04
# Epoch 90/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8434e-04
# Epoch 91/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.4328e-04
# Epoch 92/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3263e-04
# Epoch 93/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1574e-04
# Epoch 94/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9486e-04
# Epoch 95/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8323e-04
# Epoch 96/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0907e-04
# Epoch 97/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8542e-04
# Epoch 98/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9335e-04
# Epoch 99/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0580e-04
# Epoch 100/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7669e-04
# Epoch 101/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7589e-04
# Epoch 102/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7203e-04
# Epoch 103/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7398e-04
# Epoch 104/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9518e-04
# Epoch 105/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9665e-04
# Epoch 106/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2353e-04
# Epoch 107/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7281e-04
# Epoch 108/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7220e-04
# Epoch 109/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1226e-04
# Epoch 110/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7794e-04
# Epoch 111/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8415e-04
# Epoch 112/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7952e-04
# Epoch 113/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7456e-04
# Epoch 114/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9280e-04
# Epoch 115/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7702e-04
# Epoch 116/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6558e-04
# Epoch 117/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8017e-04
# Epoch 118/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0985e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9408e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8456e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9690e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8602e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0826e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6308e-04
# Epoch 125/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8947e-04
# Epoch 126/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8208e-04
# Epoch 127/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8993e-04
# Epoch 128/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6719e-04
# Epoch 129/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8282e-04
# Epoch 130/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1120e-04
# Epoch 131/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1312e-04
# Epoch 132/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8773e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0972e-04
# Epoch 134/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8045e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9776e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9817e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7146e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6978e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8356e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9407e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7323e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8527e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6228e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9347e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7582e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7305e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7132e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0153e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0418e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6805e-04
# Epoch 151/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6598e-04
# Epoch 152/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7278e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6752e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8670e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7605e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2038e-04
# Epoch 157/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9498e-04
# Epoch 158/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8035e-04
# Epoch 159/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7489e-04
# Epoch 160/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8010e-04
# Epoch 161/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7275e-04
# Epoch 162/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7454e-04
# Epoch 163/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2599e-04
# Epoch 164/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7239e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7805e-04
# Epoch 166/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6756e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6623e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6774e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6422e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0395e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8236e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6365e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9366e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8819e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9409e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0488e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7195e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6502e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8560e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6091e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6014e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6907e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8567e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8780e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0210e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8724e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0908e-04
# Epoch 188/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.6363e-04
# Epoch 189/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7432e-04
# Epoch 190/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7473e-04
# Epoch 191/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6229e-04
# Epoch 192/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7068e-04
# Epoch 193/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5825e-04
# Epoch 194/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7232e-04
# Epoch 195/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8180e-04
# Epoch 196/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8077e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8790e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8433e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7738e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6335e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7773e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9807e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4476e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6929e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9970e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2428e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8200e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6269e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7058e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9185e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9195e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8051e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8693e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9984e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5776e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6408e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8834e-04
# Epoch 218/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7932e-04
# Epoch 219/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7721e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8267e-04
# Epoch 221/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6583e-04
# Epoch 222/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6165e-04
# Epoch 223/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6846e-04
# Epoch 224/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7107e-04
# Epoch 225/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7455e-04
# Epoch 226/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.4499e-04
# Epoch 227/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8123e-04
# Epoch 228/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7460e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7856e-04
# Epoch 230/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6187e-04
# Epoch 231/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0402e-04
# Epoch 232/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7391e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7177e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9746e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6916e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6060e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6618e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6846e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8319e-04
# Epoch 240/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7252e-04
# Epoch 241/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.6362e-04
# Epoch 242/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9099e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6352e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1745e-04
# Epoch 245/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7008e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9916e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9124e-04
# Epoch 248/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6225e-04
# Epoch 249/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7052e-04
# Epoch 250/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8037e-04
# Epoch 251/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7665e-04
# Epoch 252/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7672e-04
# Epoch 253/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6241e-04
# Epoch 254/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8866e-04
# Epoch 255/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8352e-04
# Epoch 256/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6989e-04
# Epoch 257/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9301e-04
# Epoch 258/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8477e-04
# Epoch 259/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7057e-04
# Epoch 260/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8642e-04
# Epoch 261/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8128e-04
# Epoch 262/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6038e-04
# Epoch 263/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0191e-04
# Epoch 264/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7876e-04
# Epoch 265/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6993e-04
# Epoch 266/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6445e-04
# Epoch 267/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8955e-04
# Epoch 268/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6825e-04
# Epoch 269/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1809e-04
# Epoch 270/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8294e-04
# Epoch 271/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6059e-04
# Epoch 272/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1149e-04
# Epoch 273/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7550e-04
# Epoch 274/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7286e-04
# Epoch 275/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8872e-04
# Epoch 276/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9056e-04
# Epoch 277/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7346e-04
# Epoch 278/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6242e-04
# Epoch 279/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7091e-04
# Epoch 280/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6615e-04
# Epoch 281/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6217e-04
# Epoch 282/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6573e-04
# Epoch 283/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8185e-04
# Epoch 284/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8971e-04
# Epoch 285/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9462e-04
# Epoch 286/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7675e-04
# Epoch 287/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7051e-04
# Epoch 288/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5811e-04
# Epoch 289/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6122e-04
# Epoch 290/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6961e-04
# Epoch 291/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7180e-04
# Epoch 292/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6468e-04
# Epoch 293/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6446e-04
# Epoch 294/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5876e-04
# Epoch 295/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6567e-04
# Epoch 296/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6181e-04
# Epoch 297/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9669e-04
# Epoch 298/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8489e-04
# Epoch 299/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7972e-04
# Epoch 300/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9924e-04
# Epoch 1/300
# 52/52 [==============================] - 2s 6ms/step - loss: 0.0167
# Epoch 2/300
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 3/300
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 4/300
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 5/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.0800e-04
# Epoch 6/300
# 52/52 [==============================] - 0s 6ms/step - loss: 7.5013e-04
# Epoch 7/300
# 52/52 [==============================] - 0s 6ms/step - loss: 6.1197e-04
# Epoch 8/300
# 52/52 [==============================] - 0s 6ms/step - loss: 5.0856e-04
# Epoch 9/300
# 52/52 [==============================] - 0s 6ms/step - loss: 4.4334e-04
# Epoch 10/300
# 52/52 [==============================] - 0s 8ms/step - loss: 4.0948e-04
# Epoch 11/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.9850e-04
# Epoch 12/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.6919e-04
# Epoch 13/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.6342e-04
# Epoch 14/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.4287e-04
# Epoch 15/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.2766e-04
# Epoch 16/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.1415e-04
# Epoch 17/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.3675e-04
# Epoch 18/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.0368e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.1185e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.2329e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9069e-04
# Epoch 22/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.7534e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6308e-04
# Epoch 24/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6116e-04
# Epoch 25/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5803e-04
# Epoch 26/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5780e-04
# Epoch 27/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5172e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4679e-04
# Epoch 29/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4084e-04
# Epoch 30/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4241e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3499e-04
# Epoch 32/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3489e-04
# Epoch 33/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3463e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2768e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3427e-04
# Epoch 36/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1937e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3522e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3012e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1396e-04
# Epoch 40/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1676e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1482e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1773e-04
# Epoch 43/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0571e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1377e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4190e-04
# Epoch 46/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0794e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.8055e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5758e-04
# Epoch 49/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6350e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9712e-04
# Epoch 51/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1761e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0671e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.0274e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0005e-04
# Epoch 55/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0768e-04
# Epoch 56/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0682e-04
# Epoch 57/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.3685e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.2307e-04
# Epoch 59/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9578e-04
# Epoch 60/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9584e-04
# Epoch 61/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9767e-04
# Epoch 62/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.4813e-04
# Epoch 63/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.1543e-04
# Epoch 64/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1116e-04
# Epoch 65/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9319e-04
# Epoch 66/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8823e-04
# Epoch 67/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0636e-04
# Epoch 68/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9265e-04
# Epoch 69/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2198e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3755e-04
# Epoch 71/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0292e-04
# Epoch 72/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8743e-04
# Epoch 73/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2971e-04
# Epoch 74/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8993e-04
# Epoch 75/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8470e-04
# Epoch 76/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9436e-04
# Epoch 77/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3842e-04
# Epoch 78/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2615e-04
# Epoch 79/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9836e-04
# Epoch 80/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8544e-04
# Epoch 81/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8536e-04
# Epoch 82/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8669e-04
# Epoch 83/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2891e-04
# Epoch 84/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7802e-04
# Epoch 85/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4051e-04
# Epoch 86/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7618e-04
# Epoch 87/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8831e-04
# Epoch 88/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7174e-04
# Epoch 89/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7259e-04
# Epoch 90/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7561e-04
# Epoch 91/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8789e-04
# Epoch 92/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8952e-04
# Epoch 93/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5850e-04
# Epoch 94/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0362e-04
# Epoch 95/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8652e-04
# Epoch 96/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7809e-04
# Epoch 97/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7703e-04
# Epoch 98/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7907e-04
# Epoch 99/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8869e-04
# Epoch 100/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8989e-04
# Epoch 101/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8706e-04
# Epoch 102/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7511e-04
# Epoch 103/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8169e-04
# Epoch 104/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1745e-04
# Epoch 105/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7508e-04
# Epoch 106/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.1568e-04
# Epoch 107/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8333e-04
# Epoch 108/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7852e-04
# Epoch 109/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8312e-04
# Epoch 110/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6985e-04
# Epoch 111/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9384e-04
# Epoch 112/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9149e-04
# Epoch 113/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7100e-04
# Epoch 114/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2359e-04
# Epoch 115/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8935e-04
# Epoch 116/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6918e-04
# Epoch 117/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6511e-04
# Epoch 118/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7341e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8007e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9339e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9026e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9227e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0444e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9477e-04
# Epoch 125/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6871e-04
# Epoch 126/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8841e-04
# Epoch 127/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6780e-04
# Epoch 128/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7342e-04
# Epoch 129/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7819e-04
# Epoch 130/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8469e-04
# Epoch 131/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7486e-04
# Epoch 132/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7507e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8194e-04
# Epoch 134/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8103e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8064e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9278e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6735e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8461e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.0714e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.0980e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7027e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.9077e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7123e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.0752e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8247e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.8564e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9524e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7259e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.8623e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7511e-04
# Epoch 151/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8244e-04
# Epoch 152/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6771e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0729e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8339e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6803e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8803e-04
# Epoch 157/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0074e-04
# Epoch 158/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7576e-04
# Epoch 159/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7756e-04
# Epoch 160/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6877e-04
# Epoch 161/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7200e-04
# Epoch 162/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7466e-04
# Epoch 163/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8560e-04
# Epoch 164/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6899e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6299e-04
# Epoch 166/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6876e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.5957e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7825e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6115e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9385e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7004e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7005e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6973e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7446e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6858e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7577e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6627e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8312e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7856e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6247e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5988e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7197e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0574e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8425e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8783e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6581e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1177e-04
# Epoch 188/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8974e-04
# Epoch 189/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7221e-04
# Epoch 190/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7005e-04
# Epoch 191/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6700e-04
# Epoch 192/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7323e-04
# Epoch 193/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.5917e-04
# Epoch 194/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7180e-04
# Epoch 195/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9958e-04
# Epoch 196/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8633e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7559e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.5707e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7798e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6174e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8288e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8050e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8750e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6593e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7991e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9469e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8650e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6019e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6810e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7669e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8380e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7345e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7313e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7028e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5690e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6455e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7991e-04
# Epoch 218/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7228e-04
# Epoch 219/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9027e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7670e-04
# Epoch 221/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7569e-04
# Epoch 222/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6679e-04
# Epoch 223/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6751e-04
# Epoch 224/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9721e-04
# Epoch 225/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.6726e-04
# Epoch 226/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8352e-04
# Epoch 227/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.6511e-04
# Epoch 228/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6300e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7196e-04
# Epoch 230/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.5814e-04
# Epoch 231/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.8238e-04
# Epoch 232/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8236e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7455e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9752e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.5975e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6233e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6473e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6567e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7712e-04
# Epoch 240/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8053e-04
# Epoch 241/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7534e-04
# Epoch 242/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7212e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6552e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8821e-04
# Epoch 245/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6013e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8795e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8385e-04
# Epoch 248/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5839e-04
# Epoch 249/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7121e-04
# Epoch 250/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7500e-04
# Epoch 251/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6478e-04
# Epoch 252/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6853e-04
# Epoch 253/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6114e-04
# Epoch 254/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7833e-04
# Epoch 255/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6379e-04
# Epoch 256/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6353e-04
# Epoch 257/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8308e-04
# Epoch 258/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7474e-04
# Epoch 259/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6442e-04
# Epoch 260/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8200e-04
# Epoch 261/300
# ...
# Epoch 119/300
# 52/52 [==============================] - 1s 21ms/step - loss: 2.2492e-04
# Epoch 120/300
# 52/52 [==============================] - 1s 13ms/step - loss: 2.2237e-04
# Epoch 121/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2605e-04
# Epoch 122/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2182e-04
# Epoch 123/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1766e-04
# Epoch 124/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2040e-04
# Epoch 125/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2272e-04
# Epoch 126/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1585e-04
# Epoch 127/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1719e-04
# Epoch 128/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1510e-04
# Epoch 129/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1572e-04
# Epoch 130/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2017e-04
# Epoch 131/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0871e-04
# Epoch 132/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.1155e-04
# Epoch 133/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1123e-04
# Epoch 134/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1365e-04
# Epoch 135/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.0790e-04
# Epoch 136/300
# 52/52 [==============================] - 1s 15ms/step - loss: 2.1111e-04
# Epoch 137/300
# 52/52 [==============================] - 1s 16ms/step - loss: 2.0773e-04
# Epoch 138/300
# 52/52 [==============================] - 1s 16ms/step - loss: 2.0994e-04
# Epoch 139/300
# 52/52 [==============================] - 1s 15ms/step - loss: 2.1109e-04
# Epoch 140/300
# 52/52 [==============================] - 1s 16ms/step - loss: 2.0507e-04
# Epoch 141/300
# 52/52 [==============================] - 1s 17ms/step - loss: 2.0514e-04
# Epoch 142/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.0908e-04
# Epoch 143/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0602e-04
# Epoch 144/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0899e-04
# Epoch 145/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0435e-04
# Epoch 146/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1111e-04
# Epoch 147/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0612e-04
# Epoch 148/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9993e-04
# Epoch 149/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0323e-04
# Epoch 150/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0363e-04
# Epoch 151/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.9906e-04
# Epoch 152/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0928e-04
# Epoch 153/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9988e-04
# Epoch 154/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0291e-04
# Epoch 155/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0835e-04
# Epoch 156/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.9474e-04
# Epoch 157/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9830e-04
# Epoch 158/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.0260e-04
# Epoch 159/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9867e-04
# Epoch 160/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.9720e-04
# Epoch 161/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.9710e-04
# Epoch 162/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.9507e-04
# Epoch 163/300
# 52/52 [==============================] - 1s 17ms/step - loss: 2.0592e-04
# Epoch 164/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.9213e-04
# Epoch 165/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.9142e-04
# Epoch 166/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.9190e-04
# Epoch 167/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0310e-04
# Epoch 168/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0108e-04
# Epoch 169/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9788e-04
# Epoch 170/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9609e-04
# Epoch 171/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9567e-04
# Epoch 172/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9007e-04
# Epoch 173/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9021e-04
# Epoch 174/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9412e-04
# Epoch 175/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9158e-04
# Epoch 176/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9270e-04
# Epoch 177/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.9071e-04
# Epoch 178/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9623e-04
# Epoch 179/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9882e-04
# Epoch 180/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0786e-04
# Epoch 181/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8932e-04
# Epoch 182/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8561e-04
# Epoch 183/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8772e-04
# Epoch 184/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.9060e-04
# Epoch 185/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.9879e-04
# Epoch 186/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.8713e-04
# Epoch 187/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8460e-04
# Epoch 188/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.8811e-04
# Epoch 189/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8760e-04
# Epoch 190/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.9729e-04
# Epoch 191/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.8853e-04
# Epoch 192/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9788e-04
# Epoch 193/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8355e-04
# Epoch 194/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.8222e-04
# Epoch 195/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8340e-04
# Epoch 196/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8381e-04
# Epoch 197/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8386e-04
# Epoch 198/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8139e-04
# Epoch 199/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.8342e-04
# Epoch 200/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8493e-04
# Epoch 201/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9018e-04
# Epoch 202/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.8289e-04
# Epoch 203/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8296e-04
# Epoch 204/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9612e-04
# Epoch 205/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8393e-04
# Epoch 206/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8356e-04
# Epoch 207/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8696e-04
# Epoch 208/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8977e-04
# Epoch 209/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.8187e-04
# Epoch 210/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8854e-04
# Epoch 211/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8037e-04
# Epoch 212/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8236e-04
# Epoch 213/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8065e-04
# Epoch 214/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8489e-04
# Epoch 215/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.8189e-04
# Epoch 216/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7672e-04
# Epoch 217/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8305e-04
# Epoch 218/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.8479e-04
# Epoch 219/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7802e-04
# Epoch 220/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7890e-04
# Epoch 221/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8007e-04
# Epoch 222/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8285e-04
# Epoch 223/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7552e-04
# Epoch 224/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7976e-04
# Epoch 225/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7772e-04
# Epoch 226/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8134e-04
# Epoch 227/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7620e-04
# Epoch 228/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7545e-04
# Epoch 229/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7991e-04
# Epoch 230/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7731e-04
# Epoch 231/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8467e-04
# Epoch 232/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7940e-04
# Epoch 233/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7678e-04
# Epoch 234/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.7647e-04
# Epoch 235/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7892e-04
# Epoch 236/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.8139e-04
# Epoch 237/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7418e-04
# Epoch 238/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.7441e-04
# Epoch 239/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7273e-04
# Epoch 240/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7356e-04
# Epoch 241/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7598e-04
# Epoch 242/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7793e-04
# Epoch 243/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8018e-04
# Epoch 244/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7131e-04
# Epoch 245/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7142e-04
# Epoch 246/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7345e-04
# Epoch 247/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7039e-04
# Epoch 248/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7432e-04
# Epoch 249/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7016e-04
# Epoch 250/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8137e-04
# Epoch 251/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7830e-04
# Epoch 252/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7069e-04
# Epoch 253/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7202e-04
# Epoch 254/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6966e-04
# Epoch 255/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7400e-04
# Epoch 256/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8261e-04
# Epoch 257/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.7531e-04
# Epoch 258/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7223e-04
# Epoch 259/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.7384e-04
# Epoch 260/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.6871e-04
# Epoch 261/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7296e-04
# Epoch 262/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.7181e-04
# Epoch 263/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7575e-04
# Epoch 264/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7200e-04
# Epoch 265/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.6835e-04
# Epoch 266/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.6919e-04
# Epoch 267/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7034e-04
# Epoch 268/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7113e-04
# Epoch 269/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7128e-04
# Epoch 270/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.7196e-04
# Epoch 271/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7599e-04
# Epoch 272/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7264e-04
# Epoch 273/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6888e-04
# Epoch 274/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6983e-04
# Epoch 275/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7355e-04
# Epoch 276/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6990e-04
# Epoch 277/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6977e-04
# Epoch 278/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6870e-04
# Epoch 279/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6669e-04
# Epoch 280/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6782e-04
# Epoch 281/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6835e-04
# Epoch 282/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6787e-04
# Epoch 283/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7146e-04
# Epoch 284/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.6944e-04
# Epoch 285/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.6591e-04
# Epoch 286/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.6793e-04
# Epoch 287/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.6980e-04
# Epoch 288/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.6407e-04
# Epoch 289/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.6405e-04
# Epoch 290/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.6751e-04
# Epoch 291/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.7803e-04
# Epoch 292/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6391e-04
# Epoch 293/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6713e-04
# Epoch 294/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6660e-04
# Epoch 295/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6586e-04
# Epoch 296/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6642e-04
# Epoch 297/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6623e-04
# Epoch 298/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6672e-04
# Epoch 299/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6698e-04
# Epoch 300/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6349e-04
# 26/26 [==============================] - 1s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# 26/26 [==============================] - 0s 3ms/step

# %%
 #Inverse transform both train and test data
trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = range(len(data) - len(testY) - len(trainY), len(data) - len(testY))
time_index_test = range(len(data) - len(testY), len(data))

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, trainY, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, testY, label='Actual Test Close', color='blue')
plt.plot(time_index_test, gru_predictions, label='GRU Predictions', color='green')
plt.plot(time_index_test, lstm_predictions, label='LSTM Predictions', color='red')
plt.plot(time_index_test, bilstm_predictions, label='biLSTM Predictions', color='purple')
plt.plot(time_index_test, baseline_predictions, label='Baseline Predictions', color='orange')
plt.legend()
plt.show()

# %%
# Calculate the mean squared error for each model
gru_mse = mean_squared_error(testY, gru_predictions)
lstm_mse = mean_squared_error(testY, lstm_predictions)
bilstm_mse = mean_squared_error(testY, bilstm_predictions)
baseline_mse = mean_squared_error(testY, baseline_predictions)

# Compare the models using Mean Squared Error
print("GRU Model RMSE: ", np.sqrt(gru_mse))
print("LSTM Model RMSE: ", np.sqrt(lstm_mse))
print("biLSTM Model RMSE: ", np.sqrt(bilstm_mse))
print("Baseline Model RMSE: ", np.sqrt(baseline_mse))
# Out:
# GRU Model RMSE:  2631.36512202133
# LSTM Model RMSE:  2311.9228735678994
# biLSTM Model RMSE:  1766.8376485410756
# Baseline Model RMSE:  17278.326846256285

# %%
# Calculate the Mean Absolute Percentage Error (MAPE) for each model
def calculate_mape(true_values, predicted_values):
    abs_percentage_errors = np.abs((true_values - predicted_values) / true_values)
    mape = np.mean(abs_percentage_errors) * 100  # Convert to percentage
    return mape

gru_mape = calculate_mape(testY, gru_predictions)
lstm_mape = calculate_mape(testY, lstm_predictions)
bilstm_mape = calculate_mape(testY, bilstm_predictions)
baseline_mape = calculate_mape(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAPE: {:.2f}%".format(gru_mape))
print("LSTM Model MAPE: {:.2f}%".format(lstm_mape))
print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape))
print("Baseline Model MAPE: {:.2f}%".format(baseline_mape))
# Out:
# GRU Model MAPE: 2.02%
# LSTM Model MAPE: 1.74%
# biLSTM Model MAPE: 1.27%
# Baseline Model MAPE: 13.34%

# %%
def calculate_mae(true_values, predicted_values):
    abs_errors = np.abs(true_values - predicted_values)
    mae = np.mean(abs_errors)
    return mae

gru_mae = calculate_mae(testY, gru_predictions)
lstm_mae = calculate_mae(testY, lstm_predictions)
bilstm_mae = calculate_mae(testY, bilstm_predictions)
baseline_mae = calculate_mae(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAE: {:.2f}".format(gru_mae))
print("LSTM Model MAE: {:.2f}".format(lstm_mae))
print("biLSTM Model MAE: {:.2f}".format(bilstm_mae))
print("Baseline Model MAE: {:.2f}".format(baseline_mae))
# Out:
# GRU Model MAE: 2269.97
# LSTM Model MAE: 1951.68
# biLSTM Model MAE: 1410.58
# Baseline Model MAE: 15340.72

# %%
# Calculate the MASE for each model
def calculate_mase(model_mae, baseline_mae):
    mase = model_mae / baseline_mae
    return mase

gru_mase = calculate_mase(gru_mae, baseline_mae)
lstm_mase = calculate_mase(lstm_mae, baseline_mae)
bilstm_mase = calculate_mase(bilstm_mae, baseline_mae)

# Compare the models using Mean Absolute Scaled Error
print("GRU Model MASE: {:.2f}".format(gru_mase))
print("LSTM Model MASE: {:.2f}".format(lstm_mase))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase))
# Out:
# GRU Model MASE: 0.15
# LSTM Model MASE: 0.13
# biLSTM Model MASE: 0.09

# %%
# Assuming gru_predictions is your NumPy array
baseline_predictions = baseline_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=baseline_predictions, columns=['BASELINE_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('baseline_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
gru_predictions = gru_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=gru_predictions, columns=['GRU_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('gru_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
lstm_predictions = lstm_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=lstm_predictions, columns=['LSTM_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('lstm_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
trainY_predictions = trainY

# Create a DataFrame
df = pd.DataFrame(data=trainY_predictions, columns=['trainY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('trainY_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
testY_predictions = testY

# Create a DataFrame
df = pd.DataFrame(data=testY_predictions, columns=['testY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('testY_predictions.csv', index=False)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data['Close'], model='additive',period=365)
result.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data['Close'], lags=60)
plt.show()

# %%
from statsmodels.tsa.seasonal import STL
stl = STL(data['Close'], period=365,robust=True)#looking for pattern that repeats annualy
res = stl.fit()
fig = res.plot()

# %% [markdown]
# Forecasting value 1 and 2

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 30
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data2 = create_lagged_dataframe(data3, look_back, include_lag0)
#lagged_data2 = lagged_data.dropna()  # Drop rows with NaN values
lagged_data2
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Close      lag1      lag2      lag3      lag4      lag5  \
# Date
# 2007-01-02   45383.0       NaN       NaN       NaN       NaN       NaN
# 2007-01-03   44445.0   45383.0       NaN       NaN       NaN       NaN
# 2007-01-04   44020.0   44445.0   45383.0       NaN       NaN       NaN
# 2007-01-05   42245.0   44020.0   44445.0   45383.0       NaN       NaN
# 2007-01-08   42830.0   42245.0   44020.0   44445.0   45383.0       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-09  115156.0  114170.0  113284.0  113607.0  113419.0  115057.0
# 2023-10-10  116737.0  115156.0  114170.0  113284.0  113607.0  113419.0
# 2023-10-11  117051.0  116737.0  115156.0  114170.0  113284.0  113607.0
# 2023-10-13  115754.0  117051.0  116737.0  115156.0  114170.0  113284.0
# 2023-10-16  116534.0  115754.0  117051.0  116737.0  115156.0  114170.0
#
#                 lag6      lag7      lag8      lag9  ...     lag21     lag22  \
# Date                                                ...
# 2007-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-08       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-10-09  116565.0  115731.0  114327.0  114193.0  ...  115313.0  115985.0
# 2023-10-10  115057.0  116565.0  115731.0  114327.0  ...  116883.0  115313.0
# 2023-10-11  113419.0  115057.0  116565.0  115731.0  ...  117968.0  116883.0
# 2023-10-13  113607.0  113419.0  115057.0  116565.0  ...  118176.0  117968.0
# 2023-10-16  113284.0  113607.0  113419.0  115057.0  ...  119392.0  118176.0
#
#                lag23     lag24     lag25     lag26     lag27     lag28  \
# Date
# 2007-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-09  117331.0  117777.0  117893.0  115742.0  117535.0  118404.0
# 2023-10-10  115985.0  117331.0  117777.0  117893.0  115742.0  117535.0
# 2023-10-11  115313.0  115985.0  117331.0  117777.0  117893.0  115742.0
# 2023-10-13  116883.0  115313.0  115985.0  117331.0  117777.0  117893.0
# 2023-10-16  117968.0  116883.0  115313.0  115985.0  117331.0  117777.0
#
#                lag29     lag30
# Date
# 2007-01-02       NaN       NaN
# 2007-01-03       NaN       NaN
# 2007-01-04       NaN       NaN
# 2007-01-05       NaN       NaN
# 2007-01-08       NaN       NaN
# ...              ...       ...
# 2023-10-09  117121.0  115837.0
# 2023-10-10  118404.0  117121.0
# 2023-10-11  117535.0  118404.0
# 2023-10-13  115742.0  117535.0
# 2023-10-16  117893.0  115742.0
#
# [4154 rows x 31 columns]

# %%
# Save the final dataframe to a CSV file
lagged_data2.to_csv('final_data.csv', index=False)  # Setting index=False to exclude the index column

# Print the first few rows of the final dataframe
print(lagged_data2.head(7))
# Out:
#               Close     lag1     lag2     lag3     lag4     lag5     lag6  \
# Date
# 2007-01-02  45383.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2007-01-03  44445.0  45383.0      NaN      NaN      NaN      NaN      NaN
# 2007-01-04  44020.0  44445.0  45383.0      NaN      NaN      NaN      NaN
# 2007-01-05  42245.0  44020.0  44445.0  45383.0      NaN      NaN      NaN
# 2007-01-08  42830.0  42245.0  44020.0  44445.0  45383.0      NaN      NaN
# 2007-01-09  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0      NaN
# 2007-01-10  42336.0  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0
#
#             lag7  lag8  lag9  ...  lag21  lag22  lag23  lag24  lag25  lag26  \
# Date                          ...
# 2007-01-02   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-03   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-04   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-05   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-08   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-09   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-10   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#             lag27  lag28  lag29  lag30
# Date
# 2007-01-02    NaN    NaN    NaN    NaN
# 2007-01-03    NaN    NaN    NaN    NaN
# 2007-01-04    NaN    NaN    NaN    NaN
# 2007-01-05    NaN    NaN    NaN    NaN
# 2007-01-08    NaN    NaN    NaN    NaN
# 2007-01-09    NaN    NaN    NaN    NaN
# 2007-01-10    NaN    NaN    NaN    NaN
#
# [7 rows x 31 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Download data for the stock (I'm using the Bovespa index as an example)
data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 60
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data3, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values
lagged_data

# Split the data into features (X) and the target variable (Y)
X = lagged_data.drop(columns='Close')
Y = lagged_data['Close']

# Create and fit the Decision Tree model
regression_tree = DecisionTreeRegressor()
regression_tree.fit(X, Y)

# Calculate feature importances
feature_importances = regression_tree.feature_importances_

# Create a DataFrame to display feature importances
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort the features by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the top N most important features (adjust N as needed)
top_n = 10
print(importance_df.head(top_n))

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:top_n], importance_df['Importance'][:top_n])
plt.xlabel('Importance')
plt.title('Top Feature Importances')
plt.show()
#lag1 is way more important than others
# Out:
# [*********************100%%**********************]  1 of 1 completed
#    Feature  Importance
# 0     lag1    0.997551
# 1     lag2    0.000462
# 2     lag3    0.000103
# 28   lag29    0.000080
# 49   lag50    0.000072
# 40   lag41    0.000070
# 59   lag60    0.000068
# 58   lag59    0.000064
# 7     lag8    0.000061
# 8     lag9    0.000055

# %%
testX.shape
# Out:
# (825, 1, 30)

# %% [markdown]
# # Proximos 3 dias

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=3
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# array([[118036.67],
#        [117264.53],
#        [116065.85]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-09-28')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 3

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))


bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 1.01%
# LSTM Model MASE: 0.08
# LSTM Model RMSE: 1283.77
# GRU Model MAPE: 0.51%
# GRU Model MASE: 0.04
# GRU Model RMSE: 766.52
# biLSTM Model MAPE: 2.01%
# biLSTM Model MASE: 0.15
# biLSTM Model RMSE: 2374.66

# %% [markdown]
# # Proximos 7 dias

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=7
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# array([[118036.67 ],
#        [117264.53 ],
#        [116065.85 ],
#        [115716.28 ],
#        [114933.07 ],
#        [114346.625],
#        [114803.05 ]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-10-04')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 7

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))



bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 1.16%
# LSTM Model MASE: 0.09
# LSTM Model RMSE: 1586.35
# GRU Model MAPE: 1.18%
# GRU Model MASE: 0.09
# GRU Model RMSE: 1739.29
# biLSTM Model MAPE: 1.33%
# biLSTM Model MASE: 0.10
# biLSTM Model RMSE: 1772.84

# %% [markdown]
# # Proximos 15 dias (LSTM)

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=15
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 57ms/step
# array([[118036.67 ],
#        [117264.53 ],
#        [116065.85 ],
#        [115716.28 ],
#        [114933.07 ],
#        [114346.625],
#        [114803.05 ],
#        [115017.29 ],
#        [116855.96 ],
#        [117475.664],
#        [116554.88 ],
#        [116504.07 ],
#        [117417.02 ],
#        [118118.06 ],
#        [117061.914]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-10-17')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 15

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))


bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 1.08%
# LSTM Model MASE: 0.08
# LSTM Model RMSE: 1467.70
# GRU Model MAPE: 1.15%
# GRU Model MASE: 0.09
# GRU Model RMSE: 1608.78
# biLSTM Model MAPE: 1.39%
# biLSTM Model MASE: 0.10
# biLSTM Model RMSE: 1926.80
