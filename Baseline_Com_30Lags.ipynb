# %% [markdown]
# <a href="https://colab.research.google.com/github/marreapato/Forecasting-BVSP-Deep-Learning/blob/main/Baseline_Com_30Lags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tentando Aplicar o Shap

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, GRU# captum (biblioteca de interpretação pytorch)
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Download data for the stock (I'm using the Bovespa index as an example)
data = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data = data[['Close']]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(16,8))
plt.title("Pontos de Fechamento (Histórico)")
plt.plot(data["Close"])
plt.xlabel("Data",fontsize=18)
plt.ylabel("Indice Bovespa",fontsize=18)
plt.show()

# %%
look_back=30

# %%
last_rows=(len(data['Close'])-look_back)-int((len(data['Close'].values.reshape(-1, 1)[:])-look_back)*0.8)
last_rows
# Out:
# 825

# %%
size_of_slice=round((len(data['Close'].values.reshape(-1, 1)[:]))*0.8)
size_of_slice=size_of_slice+(len(data)-(size_of_slice+last_rows))
size_of_slice
# Out:
# 3329

# %%
# Normalize the data
scaler = MinMaxScaler()
data_train=pd.DataFrame(scaler.fit_transform(data['Close'].values.reshape(-1, 1)[0:size_of_slice]),columns=data.columns,index=data['Close'].index[0:size_of_slice])#use fit only in training that is wrong
data_test=pd.DataFrame(scaler.transform(data['Close'].values.reshape(-1, 1)[size_of_slice:size_of_slice+last_rows]),columns=data.columns,index=data['Close'].index[size_of_slice:size_of_slice+last_rows])#use fit only in training that is wrong

# %%
data_train=data_train.append(data_test)
# Out:
# <ipython-input-7-b2b194944e63>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_train=data_train.append(data_test)

# %%
len(data_train)==len(data)
# Out:
# True

# %%
data_train
# Out:
#                Close
# Date
# 2007-01-02  0.177017
# 2007-01-03  0.166606
# 2007-01-04  0.161888
# 2007-01-05  0.142186
# 2007-01-08  0.148680
# ...              ...
# 2023-10-09  0.951472
# 2023-10-10  0.969021
# 2023-10-11  0.972506
# 2023-10-13  0.958110
# 2023-10-16  0.966768
#
# [4154 rows x 1 columns]

# %%
# Normalize the data
#scaler = MinMaxScaler()
#data['Close'] = scaler.fit_transform(data['Close'].values.reshape(-1, 1))#use fit only in training that is wrong


def create_lagged_dataframe(data, lags, include_lag0=False):
    lagged_data = data.copy()

    if include_lag0:
        lagged_data['lag0'] = lagged_data['Close']

    for lag in range(1, lags + 1):
        lagged_data[f'lag{lag}'] = lagged_data['Close'].shift(lag)

    return lagged_data
# Split the data into train and test sets


# Create lag features for the entire dataset
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data_train, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values

train_size = int(len(lagged_data) * 0.8)
test_size = len(lagged_data) - train_size
train, test = lagged_data[0:train_size], lagged_data[train_size:len(data)]

# %%
trainX= train.drop(columns='Close').values
testX = test.drop(columns='Close').values
trainY= train['Close'].values
testY= test['Close'].values

print("TrainX shape:", trainX.shape)
print("TrainY shape:", trainY.shape)
print("TestX shape:", testX.shape)
print("TestY shape:", testY.shape)
# Out:
# TrainX shape: (3299, 30)
# TrainY shape: (3299,)
# TestX shape: (825, 30)
# TestY shape: (825,)

# %%
trainX.shape
# Out:
# (3299, 30)

# %%
trainX = np.array(trainX)
testX = np.array(testX)

# %%
import tensorflow as tf

tf.random.set_seed(22)

# Reshape the input data for LSTM and GRU models
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Define the GRU model
def GRU_Model(output_window):
    model = Sequential()
    model.add(GRU(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Define the LSTM model
def LSTM_Model(output_window):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Define the LSTM model
def biLSTM_Model(output_window):
    # n_steps = x_train.shape[-2]
    # n_features = x_train.shape[-1]
    model = Sequential()
    # model.add(tf.keras.layers.Embedding(1, 6, mask_zero=True))


    model.add(Bidirectional(LSTM(128, activation='relu', input_shape=(1, look_back), return_sequences=False)))
    #model.add(Bidirectional(LSTM(32, activation='relu', return_sequences=False)))
    #model.add(Bidirectional(LSTM(16, activation='relu')))
    # model.add(LSTM(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model






# Define the baseline model
def baseline_model(output_window):
    last_known_value = trainY[-1]
    return np.full((len(testY), output_window), last_known_value)

# Train and evaluate the models
output_window = 1
gru_model = GRU_Model(output_window)
lstm_model = LSTM_Model(output_window)
bilstm_model = biLSTM_Model(output_window)

gru_model.fit(trainX, trainY, epochs=300, batch_size=64)
lstm_model.fit(trainX, trainY, epochs=300, batch_size=64)
bilstm_model.fit(trainX, trainY, epochs=300, batch_size=64)

bilstm_predictions = bilstm_model.predict(testX)
gru_predictions = gru_model.predict(testX)
lstm_predictions = lstm_model.predict(testX)
baseline_predictions = baseline_model(output_window)

# Inverse transform the predictions
gru_predictions = scaler.inverse_transform(gru_predictions)
lstm_predictions = scaler.inverse_transform(lstm_predictions)
baseline_predictions = scaler.inverse_transform(baseline_predictions)
# Inverse transform the predictions
bilstm_predictions = scaler.inverse_transform(bilstm_predictions)
# Out:
# Epoch 1/300
# 52/52 [==============================] - 3s 4ms/step - loss: 0.0169
# Epoch 2/300
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 3/300
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 4/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 5/300
# 52/52 [==============================] - 0s 5ms/step - loss: 7.5498e-04
# Epoch 6/300
# 52/52 [==============================] - 0s 4ms/step - loss: 5.9447e-04
# Epoch 7/300
# 52/52 [==============================] - 0s 5ms/step - loss: 5.1033e-04
# Epoch 8/300
# 52/52 [==============================] - 0s 6ms/step - loss: 4.4217e-04
# Epoch 9/300
# 52/52 [==============================] - 0s 6ms/step - loss: 4.0974e-04
# Epoch 10/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.9577e-04
# Epoch 11/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.9135e-04
# Epoch 12/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.6745e-04
# Epoch 13/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.5599e-04
# Epoch 14/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.2357e-04
# Epoch 15/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.0800e-04
# Epoch 16/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.0127e-04
# Epoch 17/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9282e-04
# Epoch 18/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.8610e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.8409e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.7555e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.7725e-04
# Epoch 22/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.8236e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.7157e-04
# Epoch 24/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.1197e-04
# Epoch 25/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.6498e-04
# Epoch 26/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4163e-04
# Epoch 27/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.7067e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.3215e-04
# Epoch 29/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5087e-04
# Epoch 30/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.7311e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5435e-04
# Epoch 32/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.2282e-04
# Epoch 33/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5796e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.3646e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.2366e-04
# Epoch 36/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1845e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2572e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.6951e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0804e-04
# Epoch 40/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0752e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1279e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1110e-04
# Epoch 43/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0184e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.3280e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6159e-04
# Epoch 46/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7499e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3971e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.6104e-04
# Epoch 49/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.4671e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1406e-04
# Epoch 51/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.8094e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3419e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9743e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2736e-04
# Epoch 55/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4300e-04
# Epoch 56/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0622e-04
# Epoch 57/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9380e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9152e-04
# Epoch 59/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9016e-04
# Epoch 60/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9952e-04
# Epoch 61/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1018e-04
# Epoch 62/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.1848e-04
# Epoch 63/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2218e-04
# Epoch 64/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1413e-04
# Epoch 65/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9990e-04
# Epoch 66/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.2034e-04
# Epoch 67/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1324e-04
# Epoch 68/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0018e-04
# Epoch 69/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.1288e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1710e-04
# Epoch 71/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9878e-04
# Epoch 72/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.3179e-04
# Epoch 73/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9309e-04
# Epoch 74/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0171e-04
# Epoch 75/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8710e-04
# Epoch 76/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1212e-04
# Epoch 77/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.8589e-04
# Epoch 78/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2781e-04
# Epoch 79/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2439e-04
# Epoch 80/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8758e-04
# Epoch 81/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8263e-04
# Epoch 82/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1601e-04
# Epoch 83/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8749e-04
# Epoch 84/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0482e-04
# Epoch 85/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1456e-04
# Epoch 86/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9281e-04
# Epoch 87/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8488e-04
# Epoch 88/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0164e-04
# Epoch 89/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0181e-04
# Epoch 90/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8091e-04
# Epoch 91/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.3392e-04
# Epoch 92/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8712e-04
# Epoch 93/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.4436e-04
# Epoch 94/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1974e-04
# Epoch 95/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8891e-04
# Epoch 96/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.4487e-04
# Epoch 97/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9921e-04
# Epoch 98/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9022e-04
# Epoch 99/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1699e-04
# Epoch 100/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7639e-04
# Epoch 101/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8939e-04
# Epoch 102/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7129e-04
# Epoch 103/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8020e-04
# Epoch 104/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8235e-04
# Epoch 105/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0170e-04
# Epoch 106/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.6195e-04
# Epoch 107/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7880e-04
# Epoch 108/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7860e-04
# Epoch 109/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2477e-04
# Epoch 110/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8961e-04
# Epoch 111/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8694e-04
# Epoch 112/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8141e-04
# Epoch 113/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7499e-04
# Epoch 114/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9137e-04
# Epoch 115/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7845e-04
# Epoch 116/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7223e-04
# Epoch 117/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8498e-04
# Epoch 118/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0367e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0445e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9555e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9548e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1258e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2633e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6494e-04
# Epoch 125/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9185e-04
# Epoch 126/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8993e-04
# Epoch 127/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9459e-04
# Epoch 128/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7027e-04
# Epoch 129/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8336e-04
# Epoch 130/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9567e-04
# Epoch 131/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9782e-04
# Epoch 132/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1187e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1520e-04
# Epoch 134/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9020e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8440e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0520e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9161e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7614e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8347e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9426e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7963e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9538e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6398e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8830e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6802e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6704e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7774e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0406e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9264e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7447e-04
# Epoch 151/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6560e-04
# Epoch 152/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8035e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7001e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8863e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7362e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0294e-04
# Epoch 157/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8266e-04
# Epoch 158/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1034e-04
# Epoch 159/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7468e-04
# Epoch 160/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7961e-04
# Epoch 161/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8395e-04
# Epoch 162/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9071e-04
# Epoch 163/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.5702e-04
# Epoch 164/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7220e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8577e-04
# Epoch 166/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6821e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6574e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7117e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6674e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9423e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7701e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6319e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0033e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7918e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8081e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0714e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7389e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6220e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7524e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6393e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6513e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7068e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7931e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7791e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0204e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8901e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7204e-04
# Epoch 188/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9163e-04
# Epoch 189/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6617e-04
# Epoch 190/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6854e-04
# Epoch 191/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6755e-04
# Epoch 192/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6880e-04
# Epoch 193/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.5661e-04
# Epoch 194/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6118e-04
# Epoch 195/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8989e-04
# Epoch 196/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8611e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8042e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6191e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6679e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7084e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7857e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7918e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0241e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7032e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9542e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 4ms/step - loss: 2.0072e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7899e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7610e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7186e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8514e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0608e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8041e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1444e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2897e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5997e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6288e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8283e-04
# Epoch 218/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6785e-04
# Epoch 219/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7143e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0757e-04
# Epoch 221/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8024e-04
# Epoch 222/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6185e-04
# Epoch 223/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7065e-04
# Epoch 224/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7811e-04
# Epoch 225/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7755e-04
# Epoch 226/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4774e-04
# Epoch 227/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7010e-04
# Epoch 228/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9715e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7144e-04
# Epoch 230/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.6392e-04
# Epoch 231/300
# 52/52 [==============================] - 1s 18ms/step - loss: 2.2152e-04
# Epoch 232/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.8292e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6945e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8865e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7178e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6166e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6529e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6646e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8747e-04
# Epoch 240/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7035e-04
# Epoch 241/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6351e-04
# Epoch 242/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9332e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5944e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1182e-04
# Epoch 245/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7015e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9000e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9501e-04
# Epoch 248/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5984e-04
# Epoch 249/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7347e-04
# Epoch 250/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8150e-04
# Epoch 251/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6907e-04
# Epoch 252/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8545e-04
# Epoch 253/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6254e-04
# Epoch 254/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7117e-04
# Epoch 255/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8975e-04
# Epoch 256/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6688e-04
# Epoch 257/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2608e-04
# Epoch 258/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8952e-04
# Epoch 259/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7033e-04
# Epoch 260/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8696e-04
# Epoch 261/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7410e-04
# Epoch 262/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6351e-04
# Epoch 263/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9689e-04
# Epoch 264/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7909e-04
# Epoch 265/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7322e-04
# Epoch 266/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6628e-04
# Epoch 267/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8798e-04
# Epoch 268/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6750e-04
# Epoch 269/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8772e-04
# Epoch 270/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6758e-04
# Epoch 271/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6126e-04
# Epoch 272/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1195e-04
# Epoch 273/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7713e-04
# Epoch 274/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6725e-04
# Epoch 275/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9731e-04
# Epoch 276/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8634e-04
# Epoch 277/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7428e-04
# Epoch 278/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7250e-04
# Epoch 279/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7573e-04
# Epoch 280/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7120e-04
# Epoch 281/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6203e-04
# Epoch 282/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6773e-04
# Epoch 283/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7926e-04
# Epoch 284/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8573e-04
# Epoch 285/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8859e-04
# Epoch 286/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7094e-04
# Epoch 287/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7225e-04
# Epoch 288/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6172e-04
# Epoch 289/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6083e-04
# Epoch 290/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7489e-04
# Epoch 291/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7258e-04
# Epoch 292/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7190e-04
# Epoch 293/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6093e-04
# Epoch 294/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5902e-04
# Epoch 295/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6875e-04
# Epoch 296/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6050e-04
# Epoch 297/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0169e-04
# Epoch 298/300
# 52/52 [==============================] - 0s 4ms/step - loss: 1.8354e-04
# Epoch 299/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7546e-04
# Epoch 300/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9192e-04
# Epoch 1/300
# 52/52 [==============================] - 2s 5ms/step - loss: 0.0209
# Epoch 2/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 3/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 4/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 5/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 6/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.0920e-04
# Epoch 7/300
# 52/52 [==============================] - 0s 5ms/step - loss: 7.7966e-04
# Epoch 8/300
# 52/52 [==============================] - 0s 5ms/step - loss: 6.8256e-04
# Epoch 9/300
# 52/52 [==============================] - 0s 5ms/step - loss: 5.9859e-04
# Epoch 10/300
# 52/52 [==============================] - 0s 5ms/step - loss: 5.2375e-04
# Epoch 11/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.9353e-04
# Epoch 12/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.4862e-04
# Epoch 13/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.3022e-04
# Epoch 14/300
# 52/52 [==============================] - 0s 5ms/step - loss: 4.1175e-04
# Epoch 15/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.8651e-04
# Epoch 16/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.7420e-04
# Epoch 17/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.9664e-04
# Epoch 18/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.4797e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.5277e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.5023e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.2923e-04
# Epoch 22/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.1170e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9723e-04
# Epoch 24/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9430e-04
# Epoch 25/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.8643e-04
# Epoch 26/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.8680e-04
# Epoch 27/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.7460e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.6691e-04
# Epoch 29/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6393e-04
# Epoch 30/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6254e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5578e-04
# Epoch 32/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4950e-04
# Epoch 33/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5005e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4374e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4682e-04
# Epoch 36/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3233e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4547e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3646e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2541e-04
# Epoch 40/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2678e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2266e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2917e-04
# Epoch 43/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1344e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2068e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3741e-04
# Epoch 46/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1196e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.8284e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5748e-04
# Epoch 49/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6411e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0005e-04
# Epoch 51/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2458e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1345e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0595e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0271e-04
# Epoch 55/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0883e-04
# Epoch 56/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1156e-04
# Epoch 57/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4410e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2679e-04
# Epoch 59/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9577e-04
# Epoch 60/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0077e-04
# Epoch 61/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9762e-04
# Epoch 62/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5090e-04
# Epoch 63/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2287e-04
# Epoch 64/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0645e-04
# Epoch 65/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9439e-04
# Epoch 66/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8868e-04
# Epoch 67/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0831e-04
# Epoch 68/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9229e-04
# Epoch 69/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.2489e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.3895e-04
# Epoch 71/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0290e-04
# Epoch 72/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9156e-04
# Epoch 73/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.3277e-04
# Epoch 74/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9259e-04
# Epoch 75/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8516e-04
# Epoch 76/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9311e-04
# Epoch 77/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.3682e-04
# Epoch 78/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.2687e-04
# Epoch 79/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0079e-04
# Epoch 80/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8679e-04
# Epoch 81/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8551e-04
# Epoch 82/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9012e-04
# Epoch 83/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2238e-04
# Epoch 84/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7938e-04
# Epoch 85/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3783e-04
# Epoch 86/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7314e-04
# Epoch 87/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8629e-04
# Epoch 88/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7300e-04
# Epoch 89/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7196e-04
# Epoch 90/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7691e-04
# Epoch 91/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9033e-04
# Epoch 92/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8641e-04
# Epoch 93/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.6261e-04
# Epoch 94/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0109e-04
# Epoch 95/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8877e-04
# Epoch 96/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7868e-04
# Epoch 97/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7955e-04
# Epoch 98/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7878e-04
# Epoch 99/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8775e-04
# Epoch 100/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9255e-04
# Epoch 101/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8607e-04
# Epoch 102/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7637e-04
# Epoch 103/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8001e-04
# Epoch 104/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1168e-04
# Epoch 105/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7530e-04
# Epoch 106/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1353e-04
# Epoch 107/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8581e-04
# Epoch 108/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7935e-04
# Epoch 109/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8459e-04
# Epoch 110/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7049e-04
# Epoch 111/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9288e-04
# Epoch 112/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9061e-04
# Epoch 113/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7075e-04
# Epoch 114/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.2992e-04
# Epoch 115/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9110e-04
# Epoch 116/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6958e-04
# Epoch 117/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6493e-04
# Epoch 118/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7586e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8034e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9172e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9028e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9060e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0634e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9856e-04
# Epoch 125/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6742e-04
# Epoch 126/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9105e-04
# Epoch 127/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6808e-04
# Epoch 128/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7325e-04
# Epoch 129/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7780e-04
# Epoch 130/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8522e-04
# Epoch 131/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7406e-04
# Epoch 132/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7676e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8259e-04
# Epoch 134/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8094e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8176e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9364e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6586e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8354e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0610e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1036e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6952e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9211e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7198e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0514e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8176e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8539e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9363e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7483e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8759e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7383e-04
# Epoch 151/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8188e-04
# Epoch 152/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6828e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0502e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8247e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6645e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8938e-04
# Epoch 157/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0051e-04
# Epoch 158/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7649e-04
# Epoch 159/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7826e-04
# Epoch 160/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7047e-04
# Epoch 161/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7432e-04
# Epoch 162/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7392e-04
# Epoch 163/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8656e-04
# Epoch 164/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6894e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6223e-04
# Epoch 166/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6830e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.5968e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7971e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6205e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9395e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6930e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6879e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6838e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7539e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6899e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7558e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6481e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8039e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7996e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6427e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6091e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7401e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0261e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8214e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8607e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6480e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1347e-04
# Epoch 188/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9203e-04
# Epoch 189/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7367e-04
# Epoch 190/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7001e-04
# Epoch 191/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6691e-04
# Epoch 192/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7272e-04
# Epoch 193/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6018e-04
# Epoch 194/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7155e-04
# Epoch 195/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0104e-04
# Epoch 196/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8536e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7555e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5748e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7754e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6097e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8016e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8081e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8952e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6777e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7985e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9428e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8610e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6110e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6872e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7725e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8443e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7230e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7365e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7095e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.5677e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6519e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7879e-04
# Epoch 218/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7075e-04
# Epoch 219/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8980e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7690e-04
# Epoch 221/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7435e-04
# Epoch 222/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6620e-04
# Epoch 223/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6742e-04
# Epoch 224/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9649e-04
# Epoch 225/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6629e-04
# Epoch 226/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8440e-04
# Epoch 227/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6436e-04
# Epoch 228/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6314e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7157e-04
# Epoch 230/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5835e-04
# Epoch 231/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8263e-04
# Epoch 232/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7951e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7557e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9524e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6120e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6191e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6488e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6634e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7453e-04
# Epoch 240/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7822e-04
# Epoch 241/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7773e-04
# Epoch 242/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7541e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6501e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8930e-04
# Epoch 245/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5976e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8742e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8255e-04
# Epoch 248/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5789e-04
# Epoch 249/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7044e-04
# Epoch 250/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7343e-04
# Epoch 251/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.6516e-04
# Epoch 252/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6971e-04
# Epoch 253/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6089e-04
# Epoch 254/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8038e-04
# Epoch 255/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6351e-04
# Epoch 256/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6457e-04
# Epoch 257/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8296e-04
# Epoch 258/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.7639e-04
# Epoch 259/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6509e-04
# Epoch 260/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8082e-04
# Epoch 261/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6842e-04
# ...
# Epoch 118/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7512e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7861e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9017e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9017e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1259e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1673e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8762e-04
# Epoch 125/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7559e-04
# Epoch 126/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.8827e-04
# Epoch 127/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6947e-04
# Epoch 128/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.8135e-04
# Epoch 129/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7933e-04
# Epoch 130/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.9462e-04
# Epoch 131/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7124e-04
# Epoch 132/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7582e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8191e-04
# Epoch 134/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8002e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7707e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9315e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6791e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8548e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0175e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0755e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6783e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8722e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6726e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0661e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8283e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8941e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9560e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7228e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8686e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7219e-04
# Epoch 151/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8528e-04
# Epoch 152/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6746e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1080e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.8750e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7051e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.8269e-04
# Epoch 157/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.9656e-04
# Epoch 158/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7201e-04
# Epoch 159/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7669e-04
# Epoch 160/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7093e-04
# Epoch 161/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7337e-04
# Epoch 162/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7798e-04
# Epoch 163/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.9081e-04
# Epoch 164/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6679e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6341e-04
# Epoch 166/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7122e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5741e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7990e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6165e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9252e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7179e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7041e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6769e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7737e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6679e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7246e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6508e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8781e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7215e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6043e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5743e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7464e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0608e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8439e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8443e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6442e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.1127e-04
# Epoch 188/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.9451e-04
# Epoch 189/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7541e-04
# Epoch 190/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7150e-04
# Epoch 191/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6340e-04
# Epoch 192/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7165e-04
# Epoch 193/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.5726e-04
# Epoch 194/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7129e-04
# Epoch 195/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.9884e-04
# Epoch 196/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.8540e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7594e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.5570e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7811e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6306e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7984e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8153e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9203e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6692e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7988e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9057e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9235e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5672e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6510e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7281e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8268e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7491e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7493e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6785e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5686e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6132e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8243e-04
# Epoch 218/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7192e-04
# Epoch 219/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9426e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7641e-04
# Epoch 221/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.7640e-04
# Epoch 222/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6541e-04
# Epoch 223/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6660e-04
# Epoch 224/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.9980e-04
# Epoch 225/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6724e-04
# Epoch 226/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.8072e-04
# Epoch 227/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6700e-04
# Epoch 228/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6182e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.7313e-04
# Epoch 230/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5706e-04
# Epoch 231/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8217e-04
# Epoch 232/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8555e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7502e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8992e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5746e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6046e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6557e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6254e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7685e-04
# Epoch 240/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7937e-04
# Epoch 241/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8063e-04
# Epoch 242/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6799e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6309e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8572e-04
# Epoch 245/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5876e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8850e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8363e-04
# Epoch 248/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5686e-04
# Epoch 249/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7110e-04
# Epoch 250/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7302e-04
# Epoch 251/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6154e-04
# Epoch 252/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6529e-04
# Epoch 253/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.5747e-04
# Epoch 254/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.8391e-04
# Epoch 255/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6428e-04
# Epoch 256/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.5957e-04
# Epoch 257/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.8026e-04
# Epoch 258/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.8062e-04
# Epoch 259/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7165e-04
# Epoch 260/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7655e-04
# Epoch 261/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6516e-04
# Epoch 262/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5997e-04
# Epoch 263/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9191e-04
# Epoch 264/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6482e-04
# Epoch 265/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6005e-04
# Epoch 266/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6452e-04
# Epoch 267/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8860e-04
# Epoch 268/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6404e-04
# Epoch 269/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.0550e-04
# Epoch 270/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7991e-04
# Epoch 271/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6362e-04
# Epoch 272/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9552e-04
# Epoch 273/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6603e-04
# Epoch 274/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6892e-04
# Epoch 275/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9083e-04
# Epoch 276/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8374e-04
# Epoch 277/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8089e-04
# Epoch 278/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5562e-04
# Epoch 279/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6189e-04
# Epoch 280/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6060e-04
# Epoch 281/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6160e-04
# Epoch 282/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5836e-04
# Epoch 283/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7055e-04
# Epoch 284/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6804e-04
# Epoch 285/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6862e-04
# Epoch 286/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7550e-04
# Epoch 287/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6254e-04
# Epoch 288/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.5369e-04
# Epoch 289/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6438e-04
# Epoch 290/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.6089e-04
# Epoch 291/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6647e-04
# Epoch 292/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.5601e-04
# Epoch 293/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.5878e-04
# Epoch 294/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.5425e-04
# Epoch 295/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6809e-04
# Epoch 296/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6222e-04
# Epoch 297/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7586e-04
# Epoch 298/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9013e-04
# Epoch 299/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6887e-04
# Epoch 300/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.8285e-04
# 26/26 [==============================] - 0s 3ms/step
# 26/26 [==============================] - 0s 2ms/step
# 26/26 [==============================] - 0s 3ms/step

# %%
 #Inverse transform both train and test data
trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = range(len(data) - len(testY) - len(trainY), len(data) - len(testY))
time_index_test = range(len(data) - len(testY), len(data))

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, trainY, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, testY, label='Actual Test Close', color='blue')
plt.plot(time_index_test, gru_predictions, label='GRU Predictions', color='green')
plt.plot(time_index_test, lstm_predictions, label='LSTM Predictions', color='red')
plt.plot(time_index_test, bilstm_predictions, label='biLSTM Predictions', color='purple')
plt.plot(time_index_test, baseline_predictions, label='Baseline Predictions', color='orange')
plt.legend()
plt.show()

# %%
# Calculate the mean squared error for each model
gru_mse = mean_squared_error(testY, gru_predictions)
lstm_mse = mean_squared_error(testY, lstm_predictions)
bilstm_mse = mean_squared_error(testY, bilstm_predictions)
baseline_mse = mean_squared_error(testY, baseline_predictions)

# Compare the models using Mean Squared Error
print("GRU Model RMSE: ", np.sqrt(gru_mse))
print("LSTM Model RMSE: ", np.sqrt(lstm_mse))
print("biLSTM Model RMSE: ", np.sqrt(bilstm_mse))
print("Baseline Model RMSE: ", np.sqrt(baseline_mse))
# Out:
# GRU Model RMSE:  2509.798654907669
# LSTM Model RMSE:  2496.4761807609484
# biLSTM Model RMSE:  2055.9248591181085
# Baseline Model RMSE:  17278.326846256285

# %%
# Calculate the Mean Absolute Percentage Error (MAPE) for each model
def calculate_mape(true_values, predicted_values):
    abs_percentage_errors = np.abs((true_values - predicted_values) / true_values)
    mape = np.mean(abs_percentage_errors) * 100  # Convert to percentage
    return mape

gru_mape = calculate_mape(testY, gru_predictions)
lstm_mape = calculate_mape(testY, lstm_predictions)
bilstm_mape = calculate_mape(testY, bilstm_predictions)
baseline_mape = calculate_mape(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAPE: {:.2f}%".format(gru_mape))
print("LSTM Model MAPE: {:.2f}%".format(lstm_mape))
print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape))
print("Baseline Model MAPE: {:.2f}%".format(baseline_mape))
# Out:
# GRU Model MAPE: 1.91%
# LSTM Model MAPE: 1.89%
# biLSTM Model MAPE: 1.53%
# Baseline Model MAPE: 13.34%

# %%
def calculate_mae(true_values, predicted_values):
    abs_errors = np.abs(true_values - predicted_values)
    mae = np.mean(abs_errors)
    return mae

gru_mae = calculate_mae(testY, gru_predictions)
lstm_mae = calculate_mae(testY, lstm_predictions)
bilstm_mae = calculate_mae(testY, bilstm_predictions)
baseline_mae = calculate_mae(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAE: {:.2f}".format(gru_mae))
print("LSTM Model MAE: {:.2f}".format(lstm_mae))
print("biLSTM Model MAE: {:.2f}".format(bilstm_mae))
print("Baseline Model MAE: {:.2f}".format(baseline_mae))
# Out:
# GRU Model MAE: 2144.98
# LSTM Model MAE: 2126.64
# biLSTM Model MAE: 1711.98
# Baseline Model MAE: 15340.72

# %%
# Calculate the MASE for each model
def calculate_mase(model_mae, baseline_mae):
    mase = model_mae / baseline_mae
    return mase

gru_mase = calculate_mase(gru_mae, baseline_mae)
lstm_mase = calculate_mase(lstm_mae, baseline_mae)
bilstm_mase = calculate_mase(bilstm_mae, baseline_mae)

# Compare the models using Mean Absolute Scaled Error
print("GRU Model MASE: {:.2f}".format(gru_mase))
print("LSTM Model MASE: {:.2f}".format(lstm_mase))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase))
# Out:
# GRU Model MASE: 0.14
# LSTM Model MASE: 0.14
# biLSTM Model MASE: 0.11

# %%
# Assuming gru_predictions is your NumPy array
baseline_predictions = baseline_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=baseline_predictions, columns=['BASELINE_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('baseline_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
gru_predictions = gru_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=gru_predictions, columns=['GRU_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('gru_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
lstm_predictions = lstm_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=lstm_predictions, columns=['LSTM_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('lstm_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
trainY_predictions = trainY

# Create a DataFrame
df = pd.DataFrame(data=trainY_predictions, columns=['trainY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('trainY_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
testY_predictions = testY

# Create a DataFrame
df = pd.DataFrame(data=testY_predictions, columns=['testY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('testY_predictions.csv', index=False)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data['Close'], model='additive',period=365)
result.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data['Close'], lags=60)
plt.show()

# %%
from statsmodels.tsa.seasonal import STL
stl = STL(data['Close'], period=365,robust=True)#looking for pattern that repeats annualy
res = stl.fit()
fig = res.plot()

# %% [markdown]
# Forecasting value 1 and 2

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 30
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data2 = create_lagged_dataframe(data3, look_back, include_lag0)
#lagged_data2 = lagged_data.dropna()  # Drop rows with NaN values
lagged_data2
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Close      lag1      lag2      lag3      lag4      lag5  \
# Date
# 2007-01-02   45383.0       NaN       NaN       NaN       NaN       NaN
# 2007-01-03   44445.0   45383.0       NaN       NaN       NaN       NaN
# 2007-01-04   44020.0   44445.0   45383.0       NaN       NaN       NaN
# 2007-01-05   42245.0   44020.0   44445.0   45383.0       NaN       NaN
# 2007-01-08   42830.0   42245.0   44020.0   44445.0   45383.0       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-09  115156.0  114170.0  113284.0  113607.0  113419.0  115057.0
# 2023-10-10  116737.0  115156.0  114170.0  113284.0  113607.0  113419.0
# 2023-10-11  117051.0  116737.0  115156.0  114170.0  113284.0  113607.0
# 2023-10-13  115754.0  117051.0  116737.0  115156.0  114170.0  113284.0
# 2023-10-16  116534.0  115754.0  117051.0  116737.0  115156.0  114170.0
#
#                 lag6      lag7      lag8      lag9  ...     lag21     lag22  \
# Date                                                ...
# 2007-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2007-01-08       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-10-09  116565.0  115731.0  114327.0  114193.0  ...  115313.0  115985.0
# 2023-10-10  115057.0  116565.0  115731.0  114327.0  ...  116883.0  115313.0
# 2023-10-11  113419.0  115057.0  116565.0  115731.0  ...  117968.0  116883.0
# 2023-10-13  113607.0  113419.0  115057.0  116565.0  ...  118176.0  117968.0
# 2023-10-16  113284.0  113607.0  113419.0  115057.0  ...  119392.0  118176.0
#
#                lag23     lag24     lag25     lag26     lag27     lag28  \
# Date
# 2007-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-09  117331.0  117777.0  117893.0  115742.0  117535.0  118404.0
# 2023-10-10  115985.0  117331.0  117777.0  117893.0  115742.0  117535.0
# 2023-10-11  115313.0  115985.0  117331.0  117777.0  117893.0  115742.0
# 2023-10-13  116883.0  115313.0  115985.0  117331.0  117777.0  117893.0
# 2023-10-16  117968.0  116883.0  115313.0  115985.0  117331.0  117777.0
#
#                lag29     lag30
# Date
# 2007-01-02       NaN       NaN
# 2007-01-03       NaN       NaN
# 2007-01-04       NaN       NaN
# 2007-01-05       NaN       NaN
# 2007-01-08       NaN       NaN
# ...              ...       ...
# 2023-10-09  117121.0  115837.0
# 2023-10-10  118404.0  117121.0
# 2023-10-11  117535.0  118404.0
# 2023-10-13  115742.0  117535.0
# 2023-10-16  117893.0  115742.0
#
# [4154 rows x 31 columns]

# %%
# Save the final dataframe to a CSV file
lagged_data2.to_csv('final_data.csv', index=False)  # Setting index=False to exclude the index column

# Print the first few rows of the final dataframe
print(lagged_data2.head(7))
# Out:
#               Close     lag1     lag2     lag3     lag4     lag5     lag6  \
# Date
# 2007-01-02  45383.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2007-01-03  44445.0  45383.0      NaN      NaN      NaN      NaN      NaN
# 2007-01-04  44020.0  44445.0  45383.0      NaN      NaN      NaN      NaN
# 2007-01-05  42245.0  44020.0  44445.0  45383.0      NaN      NaN      NaN
# 2007-01-08  42830.0  42245.0  44020.0  44445.0  45383.0      NaN      NaN
# 2007-01-09  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0      NaN
# 2007-01-10  42336.0  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0
#
#             lag7  lag8  lag9  ...  lag21  lag22  lag23  lag24  lag25  lag26  \
# Date                          ...
# 2007-01-02   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-03   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-04   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-05   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-08   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-09   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2007-01-10   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#             lag27  lag28  lag29  lag30
# Date
# 2007-01-02    NaN    NaN    NaN    NaN
# 2007-01-03    NaN    NaN    NaN    NaN
# 2007-01-04    NaN    NaN    NaN    NaN
# 2007-01-05    NaN    NaN    NaN    NaN
# 2007-01-08    NaN    NaN    NaN    NaN
# 2007-01-09    NaN    NaN    NaN    NaN
# 2007-01-10    NaN    NaN    NaN    NaN
#
# [7 rows x 31 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Download data for the stock (I'm using the Bovespa index as an example)
data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 60
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data3, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values
lagged_data

# Split the data into features (X) and the target variable (Y)
X = lagged_data.drop(columns='Close')
Y = lagged_data['Close']

# Create and fit the Decision Tree model
regression_tree = DecisionTreeRegressor()
regression_tree.fit(X, Y)

# Calculate feature importances
feature_importances = regression_tree.feature_importances_

# Create a DataFrame to display feature importances
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort the features by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the top N most important features (adjust N as needed)
top_n = 10
print(importance_df.head(top_n))

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:top_n], importance_df['Importance'][:top_n])
plt.xlabel('Importance')
plt.title('Top Feature Importances')
plt.show()
#lag1 is way more important than others
# Out:
# [*********************100%%**********************]  1 of 1 completed
#    Feature  Importance
# 0     lag1    0.997553
# 1     lag2    0.000463
# 19   lag20    0.000095
# 2     lag3    0.000081
# 58   lag59    0.000069
# 33   lag34    0.000063
# 34   lag35    0.000062
# 7     lag8    0.000060
# 16   lag17    0.000060
# 8     lag9    0.000059

# %%
testX.shape
# Out:
# (825, 1, 30)

# %% [markdown]
# # Proximos 3 dias

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=3
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# array([[117031.24],
#        [116251.57],
#        [115360.78]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-09-28')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 3

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))


bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 0.72%
# LSTM Model MASE: 0.05
# LSTM Model RMSE: 962.44
# GRU Model MAPE: 0.70%
# GRU Model MASE: 0.05
# GRU Model RMSE: 907.86
# biLSTM Model MAPE: 1.22%
# biLSTM Model MASE: 0.09
# biLSTM Model RMSE: 1475.37

# %% [markdown]
# # Proximos 7 dias

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=7
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# array([[117031.24 ],
#        [116251.57 ],
#        [115360.78 ],
#        [114716.945],
#        [113907.266],
#        [113512.336],
#        [113507.48 ]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-10-04')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 7

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))



bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 1.14%
# LSTM Model MASE: 0.09
# LSTM Model RMSE: 1619.37
# GRU Model MAPE: 1.13%
# GRU Model MASE: 0.09
# GRU Model RMSE: 1613.88
# biLSTM Model MAPE: 1.18%
# biLSTM Model MASE: 0.09
# biLSTM Model RMSE: 1559.11

# %% [markdown]
# # Proximos 15 dias (LSTM)

# %%
look_back=30

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck = yf.download('^BVSP', '2007-01-01', '2023-09-22')
datacheck= datacheck[['Close']]
data2['Close'] = scaler.fit_transform(data2['Close'].values.reshape(-1, 1))
data2= data2[['Close']]

last_60_days = data2[-look_back:].values
last_60_days_scaled = last_60_days
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
X_test
#pred_price = lstm_model.predict(X_test)
#pred_price = scaler.inverse_transform(pred_price)
#print(pred_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# array([[[0.87738428, 0.87457199, 0.86218806, 0.85588261, 0.85016923,
#          0.84414995, 0.84836345, 0.83869313, 0.8557346 , 0.87526273,
#          0.86431948, 0.85258681, 0.8652569 , 0.87791713, 0.86934212,
#          0.85164938, 0.87287475, 0.8717301 , 0.86732912, 0.85404723,
#          0.84741615, 0.8629084 , 0.87361483, 0.8756673 , 0.88766639,
#          0.88141029, 0.87677248, 0.87241097, 0.88078862, 0.85562605]]])

# %%
# Use the last available data in the test set for initial prediction
current_input = X_test
# Use the last available data in the test set for initial prediction
current_input_GRU = X_test
# Use the last available data in the test set for initial prediction
current_input_bilstm = X_test

num_steps=15
# List to store multi-step predictions
multi_step_preds = []
multi_step_preds_GRU = []
multi_step_preds_bilstm = []

for step in range(num_steps):
    # Reshape current input for prediction

    # Make prediction for the next step
    next_step_pred = lstm_model.predict(current_input)
    # Make prediction for the next step
    next_step_pred_GRU = gru_model.predict(current_input_GRU)
    # Make prediction for the next step
    next_step_pred_bilstm = bilstm_model.predict(current_input_bilstm)


    # Append prediction to the list
    multi_step_preds.append(next_step_pred[0, 0])
    # Append prediction to the list
    multi_step_preds_GRU.append(next_step_pred_GRU[0, 0])
    # Append prediction to the list
    multi_step_preds_bilstm.append(next_step_pred_bilstm[0, 0])

     # Update current input for the next iteration
    current_input = np.concatenate([current_input[:, 0:, :], next_step_pred.reshape(1, 1, 1)], axis=2)[:,:,1:]
     # Update current input for the next iteration
    current_input_GRU = np.concatenate([current_input_GRU[:, 0:, :], next_step_pred_GRU.reshape(1, 1, 1)], axis=2)[:,:,1:]
# Update current input for the next iteration
    current_input_bilstm = np.concatenate([current_input_bilstm[:, 0:, :], next_step_pred_bilstm.reshape(1, 1, 1)], axis=2)[:,:,1:]


    #print(current_input)

# Inverse transform the predictions
multi_step_preds = scaler.inverse_transform(np.array(multi_step_preds).reshape(-1, 1))
multi_step_preds

multi_step_preds_GRU = scaler.inverse_transform(np.array(multi_step_preds_GRU).reshape(-1, 1))
multi_step_preds_GRU

multi_step_preds_bilstm = scaler.inverse_transform(np.array(multi_step_preds_bilstm).reshape(-1, 1))
multi_step_preds_bilstm
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# array([[117031.24 ],
#        [116251.57 ],
#        [115360.78 ],
#        [114716.945],
#        [113907.266],
#        [113512.336],
#        [113507.48 ],
#        [113213.02 ],
#        [115194.94 ],
#        [116349.84 ],
#        [115234.11 ],
#        [114589.75 ],
#        [116171.46 ],
#        [116779.53 ],
#        [115782.62 ]], dtype=float32)

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
data2test = yf.download('^BVSP', '2023-09-23', '2023-10-17')
data2test= data2test[['Close']]
len(data2test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 15

# %%
# Generate future dates for the multi-step prediction
#last_date = lagged_data.index[-1]
#future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=num_steps)


#Inverse transform both train and test data
#trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
#testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = data2.index
time_index_test = data2test.index

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, datacheck, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, data2test, label='Actual Test Close', color='orange')

# Plot the multi-step predictions
#plt.figure(figsize=(12, 6))
#plt.plot(data.index, data['Close'], label='Historical Data')
plt.plot(time_index_test, multi_step_preds, label='Multi-Step Prediction LSTM', linestyle='dashed',color='pink')
plt.plot(time_index_test, multi_step_preds_GRU, label='Multi-Step Prediction GRU', linestyle='dashed',color='red')
plt.plot(time_index_test, multi_step_preds_bilstm, label='Multi-Step Prediction BiLSTM', linestyle='dashed',color='purple')

plt.title('Multi-Step LSTM Model - Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
test_to_errors=np.array(data2test[['Close']])


lstm_mape15 = calculate_mape(test_to_errors, multi_step_preds)
lstm_mae15 = calculate_mae(test_to_errors, multi_step_preds)
lstm_mase15 = calculate_mase(lstm_mae15,baseline_mae)
lstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds))

gru_mape15 = calculate_mape(test_to_errors, multi_step_preds_GRU)
gru_mae15 = calculate_mae(test_to_errors, multi_step_preds_GRU)
gru_mase15 = calculate_mase(gru_mae15,baseline_mae)
gru_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_GRU))


bilstm_mape15 = calculate_mape(test_to_errors, multi_step_preds_bilstm)
bilstm_mae15 = calculate_mae(test_to_errors, multi_step_preds_bilstm)
bilstm_mase15 = calculate_mase(bilstm_mae15,baseline_mae)
bilstm_rmse15 = np.sqrt(mean_squared_error(test_to_errors, multi_step_preds_bilstm))




print("LSTM Model MAPE: {:.2f}%".format(lstm_mape15))
print("LSTM Model MASE: {:.2f}".format(lstm_mase15))
print("LSTM Model RMSE: {:.2f}".format(lstm_rmse15))

print("GRU Model MAPE: {:.2f}%".format(gru_mape15))
print("GRU Model MASE: {:.2f}".format(gru_mase15))
print("GRU Model RMSE: {:.2f}".format(gru_rmse15))

print("biLSTM Model MAPE: {:.2f}%".format(bilstm_mape15))
print("biLSTM Model MASE: {:.2f}".format(bilstm_mase15))
print("biLSTM Model RMSE: {:.2f}".format(bilstm_rmse15))
# Out:
# LSTM Model MAPE: 1.11%
# LSTM Model MASE: 0.08
# LSTM Model RMSE: 1518.23
# GRU Model MAPE: 1.10%
# GRU Model MASE: 0.08
# GRU Model RMSE: 1514.10
# biLSTM Model MAPE: 1.09%
# biLSTM Model MASE: 0.08
# biLSTM Model RMSE: 1473.80
