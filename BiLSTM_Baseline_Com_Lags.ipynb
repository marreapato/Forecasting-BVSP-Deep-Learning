# %% [markdown]
# Tentando Aplicar o Shap

# %%
# !pip install yfinance 
# ! pip install tensorflow
# !pip install statsmodels

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, GRU# captum (biblioteca de interpretação pytorch)
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Download data for the stock (I'm using the Bovespa index as an example)
# data = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data = pd.read_csv("data.csv")
data = data[['Close']]

# %%
data.shape
# Out:
# (4154, 1)

# %%
data.head()#.values.reshape(-1,1) #45383. 116534.
# Out:
#      Close
# 0  45383.0
# 1  44445.0
# 2  44020.0
# 3  42245.0
# 4  42830.0

# %%
plt.figure(figsize=(16,8))
plt.title("Pontos de Fechamento (Histórico)")
plt.plot(data["Close"])
plt.xlabel("Data",fontsize=18)
plt.ylabel("Indice Bovespa",fontsize=18)
plt.show()

# %%
# Normalize the data

def create_lagged_dataframe(data, lags, include_lag0=False):
    lagged_data = data.copy()

    if include_lag0:
        lagged_data['lag0'] = lagged_data['Close']

    for lag in range(1, lags + 1):
        lagged_data[f'lag{lag}'] = lagged_data['Close'].shift(lag)

    return lagged_data
# Split the data into train and test sets


# Create lag features for the entire dataset
look_back = 12
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values

scaler = MinMaxScaler()
train_size = int(len(lagged_data) * 0.8)
test_size = len(lagged_data) - train_size
train, test = lagged_data[:train_size], lagged_data[train_size:len(data)]
train.head()
# Out:
#       Close     lag1     lag2     lag3     lag4     lag5     lag6     lag7  \
# 12  42478.0  42735.0  42624.0  42919.0  43095.0  42670.0  42336.0  42007.0
# 13  43428.0  42478.0  42735.0  42624.0  42919.0  43095.0  42670.0  42336.0
# 14  43553.0  43428.0  42478.0  42735.0  42624.0  42919.0  43095.0  42670.0
# 15  44177.0  43553.0  43428.0  42478.0  42735.0  42624.0  42919.0  43095.0
# 16  44687.0  44177.0  43553.0  43428.0  42478.0  42735.0  42624.0  42919.0
#
#        lag8     lag9    lag10    lag11    lag12
# 12  42830.0  42245.0  44020.0  44445.0  45383.0
# 13  42007.0  42830.0  42245.0  44020.0  44445.0
# 14  42336.0  42007.0  42830.0  42245.0  44020.0
# 15  42670.0  42336.0  42007.0  42830.0  42245.0
# 16  43095.0  42670.0  42336.0  42007.0  42830.0

# %%
lagged_data.shape
# Out:
# (4142, 13)

# %%
trainX= train.drop(columns='Close').to_numpy()
testX = test.drop(columns='Close').to_numpy()
trainY= train['Close'].to_numpy()
testY= test['Close'].to_numpy()

print("TrainX shape:", trainX.shape)
print("TrainY shape:", trainY.shape)
print("TestX shape:", testX.shape)
print("TestY shape:", testY.shape)
# Out:
# TrainX shape: (3313, 12)
# TrainY shape: (3313,)
# TestX shape: (829, 12)
# TestY shape: (829,)

# %%
data["Close"][:train_size]
# Out:
# 0       45383.0
# 1       44445.0
# 2       44020.0
# 3       42245.0
# 4       42830.0
#          ...
# 3308    85663.0
# 3309    85469.0
# 3310    87946.0
# 3311    86949.0
# 3312    87403.0
# Name: Close, Length: 3313, dtype: float64

# %%
trainX[:,0:1]
# Out:
# array([[42735.],
#        [42478.],
#        [43428.],
#        ...,
#        [92795.],
#        [92376.],
#        [93531.]])

# %%
scaler.fit(trainX[:,0:1])
trainX[:,0:1].shape
# Out:
# (3313, 1)

# %%
scaler.min_[0], scaler.data_max_[0], #scaler.
# Out:
# (-0.3267179470103116, 119528.0)

# %%
trainX = np.apply_along_axis(lambda x: (x-scaler.min_[0])/(scaler.data_max_[0] - scaler.min_[0]),0, trainX)
testX = np.apply_along_axis(lambda x: (x-scaler.min_[0])/(scaler.data_max_[0] - scaler.min_[0]),0, testX)

trainY = np.apply_along_axis(lambda x: (x-scaler.min_[0])/(scaler.data_max_[0] - scaler.min_[0]),0, trainY)
testY = np.apply_along_axis(lambda x: (x-scaler.min_[0])/(scaler.data_max_[0] - scaler.min_[0]),0, testY)

# train = scaler.transform(train)#use fit only in training that is wrong
# testX = scaler.transform(testX.T).T#use fit only in training that is wrong

# %%
trainX
# Out:
# array([[0.35753305, 0.3566044 , 0.35907243, ..., 0.36828364, 0.37183928,
#         0.37968679],
#        [0.35538293, 0.35753305, 0.3566044 , ..., 0.3534336 , 0.36828364,
#         0.37183928],
#        [0.36333083, 0.35538293, 0.35753305, ..., 0.35832784, 0.3534336 ,
#         0.36828364],
#        ...,
#        [0.7763459 , 0.79216642, 0.8094092 , ..., 0.73123526, 0.72743699,
#         0.73577811],
#        [0.77284046, 0.7763459 , 0.79216642, ..., 0.74141694, 0.73123526,
#         0.72743699],
#        [0.78250344, 0.77284046, 0.7763459 , ..., 0.76171339, 0.74141694,
#         0.73123526]])

# %%
# trainX = np.array(trainX)
# testX = np.array(testX)

# %%
import tensorflow as tf

tf.random.set_seed(22)

# Reshape the input data for LSTM and GRU models
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# Define the GRU model
def GRU_Model(output_window):
    model = Sequential()
    model.add(GRU(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer , loss='mean_squared_error')
    return model

# Define the LSTM model
def LSTM_Model(output_window):
    # n_steps = x_train.shape[-2]
    # n_features = x_train.shape[-1]
    model = Sequential()
    # model.add(tf.keras.layers.Embedding(1, 6, mask_zero=True))


    model.add(Bidirectional(LSTM(64, activation='relu', input_shape=(output_window, 1), return_sequences=True)))
    model.add(Bidirectional(LSTM(32, activation='relu', return_sequences=True)))
    model.add(Bidirectional(LSTM(16, activation='relu')))
    # model.add(LSTM(128, return_sequences=False, input_shape=(1, look_back)))
    model.add(Dense(output_window))
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer , loss='mean_squared_error')
    return model

# Define the baseline model
def baseline_model(output_window):
    last_known_value = trainY[-1]
    return np.full((len(testY), output_window), last_known_value)

# Train and evaluate the models
output_window = 1
gru_model = GRU_Model(output_window)
lstm_model = LSTM_Model(output_window)
# lstm_model.summary()

# %%
# class LoaderX(tf.data.Dataset):
#   def __init__(self, data_x, lags, transform) -> None:
#     self.data_x = data_x
#     self.lags = lags
#     self.transform = transform
     
#   def __getitem__(self, idx):
#     def along_axis(i):
#       print(i)
#       return self.data_x.to_numpy().T[:,i:i - self.lags]
#     idxs = self.data_x.iloc[idx].index.to_numpy()
#     # lagged_data = np.apply_along_axis(lambda x: self.data_x.to_numpy()[x+1:x - self.lags:-1], idxs)
#     lagg_data = np.apply_along_axis(along_axis, 0, idxs)
#     # lagged_data = np.apply_over_axes(along_axis, idxs, 0)

#     cols  = ['Close']
#     cols.extends([f'lag{lag}' for lag in idxs])
#     return pd.DataFrame(lagg_data, columns=cols, index=idxs)
#     if include_lag0:
#         lagged_data['lag0'] = lagged_data['Close']
#     for lag in range(1, self.lags + 1):
#         lagged_data[f'lag{lag}'] = lagged_data['Close'].shift(lag)
#     return lagged_data.iloc[idx]
#   def __len__(self):
#      return len(self.data_x) - self.lags
#   # def __maxlen__(self):
#   #    return len(self.data_x) - self.lags

# %%
# le = LoaderX(data_x=data, lags = 6, transform=MinMaxScaler()) ##.first_valid_index()
# # print(len(le), type(lagged_data['Close'].shift(10)[12]), lagged_data['Close'].shift(10)[12], )
# le[15]
# # np.float64.NaN

# %%
# x_tester = np.ones((5,1,6))
# lstm_model.predict(x_tester).shape

# %%
print("gru_model")
print("*"*50)
gru_model.fit(trainX, trainY, epochs=300, batch_size=64)
print("lstm_model")
print("*"*50)
lstm_model.fit(trainX, trainY, epochs=300, batch_size=64)

gru_predictions = gru_model.predict(testX)
lstm_predictions = lstm_model.predict(testX)
baseline_predictions = baseline_model(output_window)

# Inverse transform the predictions
gru_predictions = scaler.inverse_transform(gru_predictions)
lstm_predictions = scaler.inverse_transform(lstm_predictions)
baseline_predictions = scaler.inverse_transform(baseline_predictions)
# Out:
# gru_model
# **************************************************
# Epoch 1/300
# 52/52 [==============================] - 4s 5ms/step - loss: 0.2110
# Epoch 2/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0403
# Epoch 3/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 4/300
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 5/300
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 6/300
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 7/300
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 8/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.7845e-04
# Epoch 9/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.3499e-04
# Epoch 10/300
# 52/52 [==============================] - 0s 5ms/step - loss: 8.9135e-04
# Epoch 11/300
# 52/52 [==============================] - 0s 5ms/step - loss: 8.4818e-04
# Epoch 12/300
# 52/52 [==============================] - 0s 6ms/step - loss: 8.0557e-04
# Epoch 13/300
# 52/52 [==============================] - 0s 6ms/step - loss: 7.6491e-04
# Epoch 14/300
# 52/52 [==============================] - 0s 5ms/step - loss: 7.2435e-04
# Epoch 15/300
# 52/52 [==============================] - 0s 6ms/step - loss: 6.8641e-04
# Epoch 16/300
# 52/52 [==============================] - 0s 6ms/step - loss: 6.4968e-04
# Epoch 17/300
# 52/52 [==============================] - 0s 6ms/step - loss: 6.1413e-04
# Epoch 18/300
# 52/52 [==============================] - 0s 6ms/step - loss: 5.8081e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 6ms/step - loss: 5.5070e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 7ms/step - loss: 5.2126e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 7ms/step - loss: 4.9477e-04
# Epoch 22/300
# 52/52 [==============================] - 0s 7ms/step - loss: 4.7041e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 7ms/step - loss: 4.4837e-04
# Epoch 24/300
# 52/52 [==============================] - 0s 6ms/step - loss: 4.2794e-04
# Epoch 25/300
# 52/52 [==============================] - 1s 10ms/step - loss: 4.0962e-04
# Epoch 26/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.9344e-04
# Epoch 27/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.7866e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.6553e-04
# Epoch 29/300
# 52/52 [==============================] - 1s 12ms/step - loss: 3.5511e-04
# Epoch 30/300
# 52/52 [==============================] - 1s 12ms/step - loss: 3.4432e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.3503e-04
# Epoch 32/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.2729e-04
# Epoch 33/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.2156e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.1535e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 5ms/step - loss: 3.0933e-04
# Epoch 36/300
# 52/52 [==============================] - 0s 6ms/step - loss: 3.0582e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 7ms/step - loss: 3.0147e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9862e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.9582e-04A: 0s - loss: 2.9190e
# Epoch 40/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.9317e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.9054e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.8840e-04
# Epoch 43/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.8642e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.8632e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.8392e-04
# Epoch 46/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.8182e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.8035e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.7911e-04
# Epoch 49/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7790e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.7630e-04A: 0s - loss: 1.952
# Epoch 51/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.7505e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.7343e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.7302e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.7057e-04
# Epoch 55/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6979e-04A: 0s - loss: 2.3731
# Epoch 56/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.6801e-04
# Epoch 57/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6640e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6554e-04
# Epoch 59/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.6325e-04
# Epoch 60/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.6170e-04A: 0s - loss: 2.5847e-0
# Epoch 61/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6091e-04
# Epoch 62/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.6020e-04
# Epoch 63/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5857e-04
# Epoch 64/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.5622e-04
# Epoch 65/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5528e-04
# Epoch 66/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5279e-04
# Epoch 67/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.5089e-04
# Epoch 68/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4979e-04
# Epoch 69/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4731e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4572e-04
# Epoch 71/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.4421e-04
# Epoch 72/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.4270e-04
# Epoch 73/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.4076e-04A: 0s - loss: 2.695
# Epoch 74/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3860e-04
# Epoch 75/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3676e-04
# Epoch 76/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3445e-04
# Epoch 77/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.3340e-04
# Epoch 78/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.3117e-04
# Epoch 79/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2852e-04
# Epoch 80/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2698e-04
# Epoch 81/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2559e-04
# Epoch 82/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2204e-04
# Epoch 83/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.2313e-04
# Epoch 84/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.1872e-04
# Epoch 85/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1680e-04
# Epoch 86/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1509e-04
# Epoch 87/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1295e-04
# Epoch 88/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.1071e-04
# Epoch 89/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0965e-04
# Epoch 90/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0635e-04
# Epoch 91/300
# 52/52 [==============================] - 0s 5ms/step - loss: 2.0499e-04
# Epoch 92/300
# 52/52 [==============================] - 0s 6ms/step - loss: 2.0383e-04
# Epoch 93/300
# 52/52 [==============================] - 0s 7ms/step - loss: 2.0044e-04
# Epoch 94/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.9922e-04
# Epoch 95/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9792e-04
# Epoch 96/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9618e-04
# Epoch 97/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.9141e-04
# Epoch 98/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8902e-04
# Epoch 99/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8829e-04
# Epoch 100/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8604e-04
# Epoch 101/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.8426e-04
# Epoch 102/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.8210e-04
# Epoch 103/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.7971e-04
# Epoch 104/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7770e-04
# Epoch 105/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7708e-04
# Epoch 106/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.7566e-04
# Epoch 107/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.7090e-04
# Epoch 108/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.6967e-04
# Epoch 109/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6738e-04
# Epoch 110/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.6757e-04
# Epoch 111/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6579e-04
# Epoch 112/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.6368e-04
# Epoch 113/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.6022e-04
# Epoch 114/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5742e-04
# Epoch 115/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5827e-04
# Epoch 116/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5519e-04
# Epoch 117/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5734e-04
# Epoch 118/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5474e-04
# Epoch 119/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5167e-04
# Epoch 120/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.5577e-04
# Epoch 121/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.4805e-04
# Epoch 122/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.4618e-04
# Epoch 123/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.4459e-04
# Epoch 124/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.4713e-04
# Epoch 125/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.4513e-04
# Epoch 126/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.4156e-04
# Epoch 127/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.4062e-04
# Epoch 128/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3790e-04
# Epoch 129/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3685e-04
# Epoch 130/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3837e-04
# Epoch 131/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3482e-04
# Epoch 132/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3762e-04
# Epoch 133/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3764e-04
# Epoch 134/300
# 52/52 [==============================] - ETA: 0s - loss: 1.3368e-0 - 0s 7ms/step - loss: 1.3307e-04
# Epoch 135/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.3298e-04
# Epoch 136/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2972e-04
# Epoch 137/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3494e-04
# Epoch 138/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2871e-04
# Epoch 139/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2930e-04
# Epoch 140/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2726e-04
# Epoch 141/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2777e-04
# Epoch 142/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.3247e-04
# Epoch 143/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.2563e-04
# Epoch 144/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.2831e-04
# Epoch 145/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.3192e-04
# Epoch 146/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2707e-04
# Epoch 147/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.2363e-04
# Epoch 148/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2328e-04
# Epoch 149/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2271e-04
# Epoch 150/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2118e-04
# Epoch 151/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.2026e-04
# Epoch 152/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2264e-04
# Epoch 153/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2431e-04
# Epoch 154/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.2066e-04
# Epoch 155/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1888e-04
# Epoch 156/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1877e-04
# Epoch 157/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.2044e-04
# Epoch 158/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1680e-04
# Epoch 159/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1999e-04
# Epoch 160/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.1998e-04: 0s - loss: 1.23
# Epoch 161/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1955e-04
# Epoch 162/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.1666e-04
# Epoch 163/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.1615e-04A: 0s - loss: 1.0282e
# Epoch 164/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.1577e-04
# Epoch 165/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1550e-04
# Epoch 166/300
# 52/52 [==============================] - ETA: 0s - loss: 1.1485e-0 - 0s 6ms/step - loss: 1.1474e-04
# Epoch 167/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.1674e-04
# Epoch 168/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1853e-04
# Epoch 169/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.1511e-04
# Epoch 170/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.1756e-04
# Epoch 171/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.1519e-04
# Epoch 172/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1254e-04
# Epoch 173/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1225e-04
# Epoch 174/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1552e-04
# Epoch 175/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1242e-04
# Epoch 176/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1097e-04
# Epoch 177/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1091e-04
# Epoch 178/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1142e-04
# Epoch 179/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1946e-04
# Epoch 180/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.1903e-04
# Epoch 181/300
# 52/52 [==============================] - 0s 9ms/step - loss: 1.1230e-04
# Epoch 182/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1329e-04
# Epoch 183/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1078e-04
# Epoch 184/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1064e-04
# Epoch 185/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1099e-04
# Epoch 186/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1010e-04
# Epoch 187/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0800e-04
# Epoch 188/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0862e-04
# Epoch 189/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0915e-04
# Epoch 190/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0926e-04
# Epoch 191/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0774e-04
# Epoch 192/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0751e-04
# Epoch 193/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0772e-04
# Epoch 194/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.1000e-04
# Epoch 195/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.1178e-04
# Epoch 196/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0769e-04
# Epoch 197/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0771e-04
# Epoch 198/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0734e-04
# Epoch 199/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0764e-04
# Epoch 200/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0569e-04
# Epoch 201/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0970e-04
# Epoch 202/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0743e-04
# Epoch 203/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0845e-04
# Epoch 204/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0709e-04
# Epoch 205/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0541e-04
# Epoch 206/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0503e-04
# Epoch 207/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0604e-04
# Epoch 208/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0451e-04
# Epoch 209/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0518e-04
# Epoch 210/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0359e-04
# Epoch 211/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0511e-04
# Epoch 212/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0504e-04
# Epoch 213/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0465e-04
# Epoch 214/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0470e-04
# Epoch 215/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.0284e-04
# Epoch 216/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0679e-04
# Epoch 217/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0744e-04A: 0s - loss: 1.18
# Epoch 218/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0706e-04A: 0s - loss: 8.156
# Epoch 219/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0427e-04
# Epoch 220/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0316e-04
# Epoch 221/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0512e-04
# Epoch 222/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0376e-04
# Epoch 223/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0293e-04
# Epoch 224/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0102e-04
# Epoch 225/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.0378e-04
# Epoch 226/300
# 52/52 [==============================] - 0s 8ms/step - loss: 1.0188e-04
# Epoch 227/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.9715e-05
# Epoch 228/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0037e-04
# Epoch 229/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.9975e-05
# Epoch 230/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0303e-04
# Epoch 231/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0014e-04
# Epoch 232/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0467e-04
# Epoch 233/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0151e-04
# Epoch 234/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0028e-04
# Epoch 235/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0041e-04
# Epoch 236/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0562e-04
# Epoch 237/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0071e-04
# Epoch 238/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0044e-04
# Epoch 239/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9207e-05
# Epoch 240/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8686e-05
# Epoch 241/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0423e-04
# Epoch 242/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0101e-04
# Epoch 243/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0413e-04
# Epoch 244/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9186e-05
# Epoch 245/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0017e-04
# Epoch 246/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0108e-04
# Epoch 247/300
# 52/52 [==============================] - 0s 9ms/step - loss: 9.8451e-05
# Epoch 248/300
# 52/52 [==============================] - ETA: 0s - loss: 9.6953e-0 - 0s 5ms/step - loss: 9.7981e-05
# Epoch 249/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9733e-05
# Epoch 250/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9832e-05
# Epoch 251/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8570e-05
# Epoch 252/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8428e-05
# Epoch 253/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8146e-05
# Epoch 254/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7194e-05
# Epoch 255/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0350e-04
# Epoch 256/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.9781e-05
# Epoch 257/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.9236e-05
# Epoch 258/300
# 52/52 [==============================] - 0s 6ms/step - loss: 1.0202e-04
# Epoch 259/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7858e-05
# Epoch 260/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7334e-05
# Epoch 261/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8827e-05
# Epoch 262/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9607e-05
# Epoch 263/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.6558e-05
# Epoch 264/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.8398e-05
# Epoch 265/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.6688e-05
# Epoch 266/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0116e-04
# Epoch 267/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0094e-04
# Epoch 268/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7180e-05
# Epoch 269/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7778e-05
# Epoch 270/300
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0018e-04
# Epoch 271/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8605e-05
# Epoch 272/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8955e-05
# Epoch 273/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7024e-05
# Epoch 274/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8028e-05
# Epoch 275/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.5733e-05
# Epoch 276/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7193e-05
# Epoch 277/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.5745e-05
# Epoch 278/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.5536e-05
# Epoch 279/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.4888e-05
# Epoch 280/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.6549e-05
# Epoch 281/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.4967e-05
# Epoch 282/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7637e-05
# Epoch 283/300
# 52/52 [==============================] - 0s 4ms/step - loss: 9.5870e-05
# Epoch 284/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.8539e-05
# Epoch 285/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7106e-05
# Epoch 286/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.6174e-05
# Epoch 287/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.6924e-05
# Epoch 288/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.4505e-05
# Epoch 289/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9045e-05
# Epoch 290/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.9603e-05
# Epoch 291/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.4329e-05
# Epoch 292/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.8250e-05
# Epoch 293/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.7208e-05
# Epoch 294/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.4921e-05
# Epoch 295/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.5064e-05
# Epoch 296/300
# 52/52 [==============================] - 0s 5ms/step - loss: 9.6314e-05
# Epoch 297/300
# 52/52 [==============================] - 0s 7ms/step - loss: 9.8446e-05
# Epoch 298/300
# 52/52 [==============================] - 1s 12ms/step - loss: 9.5555e-05
# Epoch 299/300
# 52/52 [==============================] - 0s 6ms/step - loss: 9.6797e-05
# Epoch 300/300
# 52/52 [==============================] - 0s 7ms/step - loss: 1.0188e-04
# lstm_model
# **************************************************
# Epoch 1/300
# 52/52 [==============================] - 14s 8ms/step - loss: 0.2921
# Epoch 2/300
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2715
# Epoch 3/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2419
# Epoch 4/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1914
# Epoch 5/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0997
# Epoch 6/300
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0177
# Epoch 7/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0103
# Epoch 8/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0086
# Epoch 9/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0070
# Epoch 10/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0057
# Epoch 11/300
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0046
# Epoch 12/300
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 13/300
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 14/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 15/300
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 16/300
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 17/300
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 18/300
# 52/52 [==============================] - 0s 8ms/step - loss: 9.4050e-04
# Epoch 19/300
# 52/52 [==============================] - 0s 8ms/step - loss: 7.6855e-04
# Epoch 20/300
# 52/52 [==============================] - 0s 8ms/step - loss: 6.5291e-04
# Epoch 21/300
# 52/52 [==============================] - 0s 9ms/step - loss: 5.7507e-04
# Epoch 22/300
# 52/52 [==============================] - 1s 11ms/step - loss: 5.2456e-04
# Epoch 23/300
# 52/52 [==============================] - 0s 9ms/step - loss: 4.8827e-04
# Epoch 24/300
# 52/52 [==============================] - 1s 19ms/step - loss: 4.6418e-04
# Epoch 25/300
# 52/52 [==============================] - 1s 11ms/step - loss: 4.4866e-04
# Epoch 26/300
# 52/52 [==============================] - 1s 10ms/step - loss: 4.3896e-04
# Epoch 27/300
# 52/52 [==============================] - 1s 10ms/step - loss: 4.3206e-04
# Epoch 28/300
# 52/52 [==============================] - 0s 9ms/step - loss: 4.2866e-04
# Epoch 29/300
# 52/52 [==============================] - 0s 9ms/step - loss: 4.1903e-04
# Epoch 30/300
# 52/52 [==============================] - 1s 12ms/step - loss: 4.1408e-04
# Epoch 31/300
# 52/52 [==============================] - 0s 9ms/step - loss: 4.0941e-04
# Epoch 32/300
# 52/52 [==============================] - 1s 10ms/step - loss: 4.0255e-04
# Epoch 33/300
# 52/52 [==============================] - 1s 14ms/step - loss: 3.9956e-04
# Epoch 34/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.9399e-04
# Epoch 35/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.8895e-04
# Epoch 36/300
# 52/52 [==============================] - 1s 10ms/step - loss: 3.8538e-04
# Epoch 37/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.8056e-04
# Epoch 38/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.7717e-04
# Epoch 39/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.6963e-04
# Epoch 40/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.6538e-04
# Epoch 41/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.6228e-04
# Epoch 42/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.5392e-04
# Epoch 43/300
# 52/52 [==============================] - 1s 11ms/step - loss: 3.4790e-04
# Epoch 44/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.4717e-04
# Epoch 45/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.4077e-04
# Epoch 46/300
# 52/52 [==============================] - 1s 10ms/step - loss: 3.3580e-04
# Epoch 47/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.3001e-04
# Epoch 48/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.2569e-04
# Epoch 49/300
# 52/52 [==============================] - 1s 11ms/step - loss: 3.2014e-04
# Epoch 50/300
# 52/52 [==============================] - 0s 9ms/step - loss: 3.1859e-04
# Epoch 51/300
# 52/52 [==============================] - 1s 11ms/step - loss: 3.1272e-04
# Epoch 52/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.0831e-04
# Epoch 53/300
# 52/52 [==============================] - 0s 8ms/step - loss: 3.0331e-04
# Epoch 54/300
# 52/52 [==============================] - 0s 8ms/step - loss: 2.9817e-04
# Epoch 55/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.9560e-04
# Epoch 56/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.9128e-04
# Epoch 57/300
# 52/52 [==============================] - 1s 13ms/step - loss: 2.8668e-04
# Epoch 58/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.8597e-04
# Epoch 59/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.7915e-04
# Epoch 60/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.7571e-04
# Epoch 61/300
# 52/52 [==============================] - 1s 13ms/step - loss: 2.7289e-04
# Epoch 62/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.7482e-04: 0s - loss: 2.7855e-0
# Epoch 63/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.6773e-04
# Epoch 64/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.6711e-04
# Epoch 65/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.6352e-04
# Epoch 66/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.6096e-04
# Epoch 67/300
# 52/52 [==============================] - 1s 10ms/step - loss: 2.5573e-04
# Epoch 68/300
# 52/52 [==============================] - 1s 13ms/step - loss: 2.5385e-04
# Epoch 69/300
# 52/52 [==============================] - 1s 13ms/step - loss: 2.5003e-04
# Epoch 70/300
# 52/52 [==============================] - 0s 9ms/step - loss: 2.4517e-04
# Epoch 71/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.4247e-04
# Epoch 72/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.3924e-04
# Epoch 73/300
# 52/52 [==============================] - 1s 15ms/step - loss: 2.3856e-04
# Epoch 74/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.3534e-04
# Epoch 75/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.3385e-04
# Epoch 76/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.3011e-04
# Epoch 77/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.2796e-04
# Epoch 78/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2364e-04
# Epoch 79/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.2029e-04
# Epoch 80/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.2149e-04
# Epoch 81/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.1517e-04
# Epoch 82/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.1162e-04
# Epoch 83/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.1178e-04
# Epoch 84/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.0937e-04
# Epoch 85/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.0519e-04
# Epoch 86/300
# 52/52 [==============================] - 1s 11ms/step - loss: 2.0787e-04
# Epoch 87/300
# 52/52 [==============================] - 1s 14ms/step - loss: 2.0711e-04
# Epoch 88/300
# 52/52 [==============================] - 1s 12ms/step - loss: 2.0037e-04
# Epoch 89/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9756e-04
# Epoch 90/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9540e-04
# Epoch 91/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.9210e-04: 0s - loss:
# Epoch 92/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.9622e-04
# Epoch 93/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.9164e-04
# Epoch 94/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8734e-04
# Epoch 95/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8689e-04
# Epoch 96/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.8809e-04: 0s - loss: 1.7183
# Epoch 97/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.8039e-04
# Epoch 98/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7927e-04
# Epoch 99/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7798e-04
# Epoch 100/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.7881e-04
# Epoch 101/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7513e-04
# Epoch 102/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7629e-04
# Epoch 103/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7070e-04
# Epoch 104/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.7033e-04
# Epoch 105/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.7111e-04: 0s - loss: 1.7111e-0
# Epoch 106/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.7104e-04
# Epoch 107/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6877e-04
# Epoch 108/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.6776e-04
# Epoch 109/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.6809e-04
# Epoch 110/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.6604e-04
# Epoch 111/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6253e-04
# Epoch 112/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6844e-04
# Epoch 113/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.6188e-04: 0s - loss: 1.68
# Epoch 114/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.5758e-04
# Epoch 115/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.5905e-04
# Epoch 116/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.5870e-04
# Epoch 117/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.6682e-04
# Epoch 118/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.5571e-04
# Epoch 119/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.5574e-04
# Epoch 120/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.5733e-04
# Epoch 121/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.5396e-04
# Epoch 122/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.5292e-04
# Epoch 123/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.5254e-04: 0s - loss:
# Epoch 124/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5625e-04
# Epoch 125/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.5367e-04: 0s - loss: 1.5315e- - ETA: 0s - loss: 1.5353e-0
# Epoch 126/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.5002e-04
# Epoch 127/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.4908e-04
# Epoch 128/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4896e-04
# Epoch 129/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4673e-04
# Epoch 130/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4868e-04
# Epoch 131/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.4824e-04
# Epoch 132/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4973e-04
# Epoch 133/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4840e-04
# Epoch 134/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4589e-04
# Epoch 135/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4570e-04
# Epoch 136/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4367e-04
# Epoch 137/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.4619e-04
# Epoch 138/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.4381e-04
# Epoch 139/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4328e-04
# Epoch 140/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4468e-04
# Epoch 141/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.4589e-04
# Epoch 142/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4423e-04
# Epoch 143/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.4131e-04
# Epoch 144/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.4158e-04: 0s - loss: 1
# Epoch 145/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.4346e-04
# Epoch 146/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4377e-04
# Epoch 147/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.3941e-04
# Epoch 148/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.3989e-04
# Epoch 149/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3871e-04
# Epoch 150/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3798e-04
# Epoch 151/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3857e-04
# Epoch 152/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.4063e-04
# Epoch 153/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.4301e-04
# Epoch 154/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3996e-04
# Epoch 155/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.3677e-04
# Epoch 156/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.3612e-04
# Epoch 157/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.4121e-04
# Epoch 158/300
# 52/52 [==============================] - 1s 21ms/step - loss: 1.3647e-04
# Epoch 159/300
# 52/52 [==============================] - 2s 29ms/step - loss: 1.3881e-04
# Epoch 160/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.4077e-04
# Epoch 161/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.3769e-04
# Epoch 162/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.3538e-04
# Epoch 163/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.3507e-04
# Epoch 164/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3514e-04
# Epoch 165/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3853e-04
# Epoch 166/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.3496e-04
# Epoch 167/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3654e-04
# Epoch 168/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3737e-04: 0s - loss: 1.
# Epoch 169/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.3437e-04
# Epoch 170/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3966e-04
# Epoch 171/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3455e-04
# Epoch 172/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3202e-04
# Epoch 173/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3174e-04
# Epoch 174/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3572e-04
# Epoch 175/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3376e-04
# Epoch 176/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.3169e-04
# Epoch 177/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3056e-04
# Epoch 178/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3059e-04
# Epoch 179/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.4268e-04
# Epoch 180/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.4456e-04
# Epoch 181/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3116e-04
# Epoch 182/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3483e-04
# Epoch 183/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.3085e-04: 0s - loss:
# Epoch 184/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3044e-04
# Epoch 185/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3251e-04
# Epoch 186/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3028e-04: 0s - loss: 1.3243
# Epoch 187/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2907e-04
# Epoch 188/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2826e-04
# Epoch 189/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2817e-04
# Epoch 190/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2977e-04
# Epoch 191/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2871e-04
# Epoch 192/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2820e-04
# Epoch 193/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2893e-04
# Epoch 194/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.3167e-04
# Epoch 195/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.3250e-04
# Epoch 196/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2751e-04
# Epoch 197/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2928e-04
# Epoch 198/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2824e-04
# Epoch 199/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2744e-04
# Epoch 200/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2717e-04
# Epoch 201/300
# 52/52 [==============================] - 1s 10ms/step - loss: 1.3329e-04
# Epoch 202/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2525e-04
# Epoch 203/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3105e-04
# Epoch 204/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2919e-04
# Epoch 205/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2509e-04
# Epoch 206/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2510e-04: 0s - loss: 1.2536e-0
# Epoch 207/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2540e-04
# Epoch 208/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2591e-04
# Epoch 209/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2592e-04
# Epoch 210/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2492e-04
# Epoch 211/300
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2787e-04: 0s - loss: 1.3033e
# Epoch 212/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.2643e-04
# Epoch 213/300
# 52/52 [==============================] - 2s 36ms/step - loss: 1.2508e-04
# Epoch 214/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2410e-04
# Epoch 215/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.2248e-04: 0s - loss: 1.2625e-0 - ETA: 0s - loss: 1.246
# Epoch 216/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.2778e-04
# Epoch 217/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2907e-04
# Epoch 218/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.3144e-04
# Epoch 219/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2516e-04
# Epoch 220/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2396e-04
# Epoch 221/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2746e-04
# Epoch 222/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2527e-04
# Epoch 223/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.2384e-04
# Epoch 224/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2141e-04
# Epoch 225/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2694e-04
# Epoch 226/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2435e-04
# Epoch 227/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2076e-04: 0s - loss: 1.20
# Epoch 228/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2261e-04
# Epoch 229/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2052e-04
# Epoch 230/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2575e-04
# Epoch 231/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2289e-04: 0s - loss: 1.247
# Epoch 232/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2434e-04: 0s - loss: 1.17
# Epoch 233/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2171e-04
# Epoch 234/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2055e-04
# Epoch 235/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2120e-04
# Epoch 236/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2919e-04
# Epoch 237/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2162e-04: 0s - loss: 1.2068
# Epoch 238/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2207e-04
# Epoch 239/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1905e-04
# Epoch 240/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1982e-04
# Epoch 241/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2376e-04: 0s - loss: 1
# Epoch 242/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2100e-04
# Epoch 243/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2712e-04
# Epoch 244/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2286e-04
# Epoch 245/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2132e-04
# Epoch 246/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.2165e-04
# Epoch 247/300
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1873e-04
# Epoch 248/300
# 52/52 [==============================] - 2s 29ms/step - loss: 1.1907e-04
# Epoch 249/300
# 52/52 [==============================] - 1s 21ms/step - loss: 1.1771e-04
# Epoch 250/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.2021e-04
# Epoch 251/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1728e-04
# Epoch 252/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1808e-04
# Epoch 253/300
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1819e-04
# Epoch 254/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1662e-04
# Epoch 255/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2736e-04
# Epoch 256/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2190e-04
# Epoch 257/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1860e-04
# Epoch 258/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2066e-04
# Epoch 259/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1670e-04: 0s - loss: 1.20
# Epoch 260/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1738e-04
# Epoch 261/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.2406e-04
# Epoch 262/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1.1917e-04
# Epoch 263/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1744e-04
# Epoch 264/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.2120e-04
# Epoch 265/300
# 52/52 [==============================] - 1s 22ms/step - loss: 1.1798e-04
# Epoch 266/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.2481e-04
# Epoch 267/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.2304e-04
# Epoch 268/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.1550e-04
# Epoch 269/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1881e-04
# Epoch 270/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1713e-04
# Epoch 271/300
# 52/52 [==============================] - 1s 18ms/step - loss: 1.1743e-04
# Epoch 272/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1924e-04
# Epoch 273/300
# 52/52 [==============================] - 1s 17ms/step - loss: 1.1678e-04
# Epoch 274/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1719e-04
# Epoch 275/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1531e-04
# Epoch 276/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1841e-04
# Epoch 277/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1711e-04: 0s - loss: 1.
# Epoch 278/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1500e-04
# Epoch 279/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1452e-04: 0s - loss: 1.1599e-
# Epoch 280/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1826e-04: 0s - loss: 1
# Epoch 281/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1516e-04: 0s - loss: 9.
# Epoch 282/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1474e-04
# Epoch 283/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1666e-04
# Epoch 284/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1551e-04
# Epoch 285/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1459e-04
# Epoch 286/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1524e-04
# Epoch 287/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1513e-04: 0s - loss: 1
# Epoch 288/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1428e-04
# Epoch 289/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1897e-04
# Epoch 290/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1822e-04
# Epoch 291/300
# 52/52 [==============================] - 1s 13ms/step - loss: 1.1367e-04
# Epoch 292/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1922e-04
# Epoch 293/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1653e-04: 0s - loss: 1.1751
# Epoch 294/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1531e-04
# Epoch 295/300
# 52/52 [==============================] - 1s 12ms/step - loss: 1.1753e-04
# Epoch 296/300
# 52/52 [==============================] - 1s 14ms/step - loss: 1.1689e-04: 0s - loss: 1.1699e-0
# Epoch 297/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1890e-04
# Epoch 298/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1404e-04
# Epoch 299/300
# 52/52 [==============================] - 1s 11ms/step - loss: 1.1525e-04
# Epoch 300/300
# 52/52 [==============================] - 1s 15ms/step - loss: 1.1973e-04: 0s - loss: 1.25

# %%
 #Inverse transform both train and test data
trainY = scaler.inverse_transform(trainY.reshape(-1, 1))
testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Create a time index for plotting
time_index_train = range(len(data) - len(testY) - len(trainY), len(data) - len(testY))
time_index_test = range(len(data) - len(testY), len(data))

# Plot all true values and the predictions with different colors
plt.figure(figsize=(12, 6))
plt.plot(time_index_train, trainY, label='Actual Train Close', color='blue', linestyle='dotted')
plt.plot(time_index_test, testY, label='Actual Test Close', color='blue')
plt.plot(time_index_test, gru_predictions, label='GRU Predictions', color='green')
plt.plot(time_index_test, lstm_predictions, label='LSTM Predictions', color='red')
plt.plot(time_index_test, baseline_predictions, label='Baseline Predictions', color='orange')
plt.legend()
plt.show()

# %%
# Calculate the mean squared error for each model
gru_mse = mean_squared_error(testY, gru_predictions)
lstm_mse = mean_squared_error(testY, lstm_predictions)
baseline_mse = mean_squared_error(testY, baseline_predictions)

# Compare the models using Mean Squared Error
print("GRU Model RMSE: ", np.sqrt(gru_mse))
print("LSTM Model RMSE: ", np.sqrt(lstm_mse))
print("Baseline Model RMSE: ", np.sqrt(baseline_mse))
# Out:
# GRU Model RMSE:  1197.1348430720789
# LSTM Model RMSE:  1492.4996756113528
# Baseline Model RMSE:  13277.737875690242

# %%
# Calculate the Mean Absolute Percentage Error (MAPE) for each model
def calculate_mape(true_values, predicted_values):
    abs_percentage_errors = np.abs((true_values - predicted_values) / true_values)
    mape = np.mean(abs_percentage_errors) * 100  # Convert to percentage
    return mape

gru_mape = calculate_mape(testY, gru_predictions)
lstm_mape = calculate_mape(testY, lstm_predictions)
baseline_mape = calculate_mape(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAPE: {:.2f}%".format(gru_mape))
print("LSTM Model MAPE: {:.2f}%".format(lstm_mape))
print("Baseline Model MAPE: {:.2f}%".format(baseline_mape))
# Out:
# GRU Model MAPE: 0.84%
# LSTM Model MAPE: 1.04%
# Baseline Model MAPE: 10.18%

# %%
def calculate_mae(true_values, predicted_values):
    abs_errors = np.abs(true_values - predicted_values)
    mae = np.mean(abs_errors)
    return mae

gru_mae = calculate_mae(testY, gru_predictions)
lstm_mae = calculate_mae(testY, lstm_predictions)
baseline_mae = calculate_mae(testY, baseline_predictions)

# Compare the models using Mean Absolute Percentage Error
print("GRU Model MAE: {:.2f}".format(gru_mae))
print("LSTM Model MAE: {:.2f}".format(lstm_mae))
print("Baseline Model MAE: {:.2f}".format(baseline_mae))
# Out:
# GRU Model MAE: 951.32
# LSTM Model MAE: 1174.31
# Baseline Model MAE: 11819.37

# %%
# Calculate the MASE for each model
def calculate_mase(model_mae, baseline_mae):
    mase = model_mae / baseline_mae
    return mase

gru_mase = calculate_mase(gru_mae, baseline_mae)
lstm_mase = calculate_mase(lstm_mae, baseline_mae)

# Compare the models using Mean Absolute Scaled Error
print("GRU Model MASE: {:.2f}".format(gru_mase))
print("LSTM Model MASE: {:.2f}".format(lstm_mase))
# Out:
# GRU Model MASE: 0.08
# LSTM Model MASE: 0.10

# %%
# Assuming gru_predictions is your NumPy array
baseline_predictions = baseline_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=baseline_predictions, columns=['BASELINE_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('baseline_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
gru_predictions = gru_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=gru_predictions, columns=['GRU_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('gru_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
lstm_predictions = lstm_predictions.reshape(-1, 1)  # Reshape the array to have one column

# Create a DataFrame
df = pd.DataFrame(data=lstm_predictions, columns=['LSTM_Predictions'])

# Save the DataFrame to a CSV file
df.to_csv('lstm_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
trainY_predictions = trainY

# Create a DataFrame
df = pd.DataFrame(data=trainY_predictions, columns=['trainY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('trainY_predictions.csv', index=False)

# %%
# Assuming gru_predictions is your NumPy array
testY_predictions = testY

# Create a DataFrame
df = pd.DataFrame(data=testY_predictions, columns=['testY_predictions'])

# Save the DataFrame to a CSV file
df.to_csv('testY_predictions.csv', index=False)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data['Close'], model='additive',period=365)
result.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data['Close'], lags=60)
plt.show()

# %%
from statsmodels.tsa.seasonal import STL
stl = STL(data['Close'], period=365,robust=True)#looking for pattern that repeats annualy
res = stl.fit()
fig = res.plot()

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
# data2 = yf.download('^BVSP', '2007-01-01', '2023-09-22')
data2 = pd.read_csv("data.csv")
data2= data2[['Close']]
data2

last_60_days = data2[-look_back:].values
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1,X_test.shape[1])
pred_price = lstm_model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[115168.89]]

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
# data2 = yf.download('^BVSP', '2023-09-23', '2023-09-26')
data2 = pd.read_csv("data.csv")
data2= data2[['Close']]
data2
# Out:
#          Close
# 0      45383.0
# 1      44445.0
# 2      44020.0
# 3      42245.0
# 4      42830.0
# ...        ...
# 4149  115156.0
# 4150  116737.0
# 4151  117051.0
# 4152  115754.0
# 4153  116534.0
#
# [4154 rows x 1 columns]

# %%
# Download data for the stock (I'm using the Bovespa index as an example)
# data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = pd.read_csv("data.csv")

data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 6
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data2 = create_lagged_dataframe(data3, look_back, include_lag0)
#lagged_data2 = lagged_data.dropna()  # Drop rows with NaN values
lagged_data2
# Out:
#          Close      lag1      lag2      lag3      lag4      lag5      lag6
# 0      45383.0       NaN       NaN       NaN       NaN       NaN       NaN
# 1      44445.0   45383.0       NaN       NaN       NaN       NaN       NaN
# 2      44020.0   44445.0   45383.0       NaN       NaN       NaN       NaN
# 3      42245.0   44020.0   44445.0   45383.0       NaN       NaN       NaN
# 4      42830.0   42245.0   44020.0   44445.0   45383.0       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 4149  115156.0  114170.0  113284.0  113607.0  113419.0  115057.0  116565.0
# 4150  116737.0  115156.0  114170.0  113284.0  113607.0  113419.0  115057.0
# 4151  117051.0  116737.0  115156.0  114170.0  113284.0  113607.0  113419.0
# 4152  115754.0  117051.0  116737.0  115156.0  114170.0  113284.0  113607.0
# 4153  116534.0  115754.0  117051.0  116737.0  115156.0  114170.0  113284.0
#
# [4154 rows x 7 columns]

# %%
# Save the final dataframe to a CSV file
lagged_data2.to_csv('final_data.csv', index=False)  # Setting index=False to exclude the index column

# Print the first few rows of the final dataframe
print(lagged_data2.head(7))
# Out:
#      Close     lag1     lag2     lag3     lag4     lag5     lag6
# 0  45383.0      NaN      NaN      NaN      NaN      NaN      NaN
# 1  44445.0  45383.0      NaN      NaN      NaN      NaN      NaN
# 2  44020.0  44445.0  45383.0      NaN      NaN      NaN      NaN
# 3  42245.0  44020.0  44445.0  45383.0      NaN      NaN      NaN
# 4  42830.0  42245.0  44020.0  44445.0  45383.0      NaN      NaN
# 5  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0      NaN
# 6  42336.0  42007.0  42830.0  42245.0  44020.0  44445.0  45383.0

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Download data for the stock (I'm using the Bovespa index as an example)
# data3 = yf.download('^BVSP', '2007-01-01', '2023-10-17')
data3 = pd.read_csv("data.csv")

data3 = data3[['Close']]

# Create lag features for the entire dataset
look_back = 60
include_lag0 = False  # You can set this to True if you want to include lag0

lagged_data = create_lagged_dataframe(data3, look_back, include_lag0)
lagged_data = lagged_data.dropna()  # Drop rows with NaN values
lagged_data

# Split the data into features (X) and the target variable (Y)
X = lagged_data.drop(columns='Close')
Y = lagged_data['Close']

# Create and fit the Decision Tree model
regression_tree = DecisionTreeRegressor()
regression_tree.fit(X, Y)

# Calculate feature importances
feature_importances = regression_tree.feature_importances_

# Create a DataFrame to display feature importances
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort the features by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the top N most important features (adjust N as needed)
top_n = 10
print(importance_df.head(top_n))

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:top_n], importance_df['Importance'][:top_n])
plt.xlabel('Importance')
plt.title('Top Feature Importances')
plt.show()
#lag1 is way more important than others
# Out:
#    Feature  Importance
# 0     lag1    0.997555
# 1     lag2    0.000457
# 53   lag54    0.000089
# 43   lag44    0.000076
# 2     lag3    0.000075
# 14   lag15    0.000067
# 58   lag59    0.000066
# 59   lag60    0.000061
# 4     lag5    0.000060
# 8     lag9    0.000057
